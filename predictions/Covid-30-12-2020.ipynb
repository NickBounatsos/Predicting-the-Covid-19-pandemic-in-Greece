# %% [markdown]
# # Covid-19 Overview in Greece

# %% [markdown]
# ## Table of contents
# * [Introduction](#introduction)
# * [Data](#data)
# * [New cases graph](#new_cases_graph)
# * [New deaths graph](#new_deaths_graph)
# * [Total cases graph](#total_cases_graph)
# * [Total deaths graph](#total_deaths_graph)
# * [Prediction of new deaths](#prediction_new_deaths)
# * [Prediction of new cases](#prediction_new_cases)

# %% [markdown]
# # Introduction <a name="introduction"></a>

# %% [markdown]
# ## Data <a name="data"></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from matplotlib.ticker import StrMethodFormatter
import seaborn as sns
import scipy
import plotly
import folium
from folium import plugins
import statsmodels.formula.api as smf
import statsmodels.api as sm
from sklearn import model_selection, preprocessing, feature_selection, ensemble, linear_model, metrics, decomposition
from lime import lime_tabular
import plotly.express as px
import plotly.graph_objects as go
import os
import pandas as pd
#from datetime import datetime
import datetime

# %%
#!wget -nv https://covid19.who.int/WHO-COVID-19-global-data.csv
#print('File downloaded!')
file_name=('cov.csv')
df_raw=pd.read_csv(file_name)
print('File copied to DataFrame!')
#os.remove("WHO-COVID-19-global-data.csv")
#print("File Removed!")
# Out:
# File copied to DataFrame!

# %%
predicted_new_cases_file_name = 'predicted_new_cases_for_' + str((datetime.datetime.today() + datetime.timedelta(days=1)).strftime('%d-%m-%Y')) + '.csv'
predicted_new_deaths_file_name = 'predicted_new_deaths_for_' + str((datetime.datetime.today() + datetime.timedelta(days=1)).strftime('%d-%m-%Y')) + '.csv'
predicted_new_intubated_file_name = 'predicted_new_intubated_for_' + str((datetime.datetime.today() + datetime.timedelta(days=1)).strftime('%d-%m-%Y')) + '.csv'
actual_new_cases_file_name = 'actual_new_cases_for_' + str(datetime.datetime.now().strftime('%d-%m-%Y')) + '.csv'
actual_new_deaths_file_name = 'actual_new_deaths_for_' + str(datetime.datetime.now().strftime('%d-%m-%Y')) + '.csv'
actual_new_intubated_file_name = 'actual_new_intubated_for_' + str(datetime.datetime.now().strftime('%d-%m-%Y')) + '.csv'

# %%
df_raw.head()
# Out:
#   Date_reported Country_code      Country WHO_region  New_cases  \
# 0    2020-01-03           AF  Afghanistan       EMRO          0
# 1    2020-01-04           AF  Afghanistan       EMRO          0
# 2    2020-01-05           AF  Afghanistan       EMRO          0
# 3    2020-01-06           AF  Afghanistan       EMRO          0
# 4    2020-01-07           AF  Afghanistan       EMRO          0
#
#    Cumulative_cases  New_deaths  Cumulative_deaths  intubated
# 0                 0           0                  0        NaN
# 1                 0           0                  0        NaN
# 2                 0           0                  0        NaN
# 3                 0           0                  0        NaN
# 4                 0           0                  0        NaN

# %% [markdown]
# #### Removing data from all the countries except Greece

# %%
df_raw=df_raw[df_raw['Country'].str.contains('Greece')]
df_raw.head()
# Out:
#       Date_reported Country_code Country WHO_region  New_cases  \
# 28269    2020-01-03           GR  Greece       EURO          0
# 28270    2020-01-04           GR  Greece       EURO          0
# 28271    2020-01-05           GR  Greece       EURO          0
# 28272    2020-01-06           GR  Greece       EURO          0
# 28273    2020-01-07           GR  Greece       EURO          0
#
#        Cumulative_cases  New_deaths  Cumulative_deaths  intubated
# 28269                 0           0                  0        NaN
# 28270                 0           0                  0        NaN
# 28271                 0           0                  0        NaN
# 28272                 0           0                  0        NaN
# 28273                 0           0                  0        NaN

# %% [markdown]
# #### Removing unnecessary data columns

# %%
df_raw.drop(columns=["Country_code", "WHO_region", "Country"], inplace=True)
df_raw.head()
# Out:
#       Date_reported  New_cases  Cumulative_cases  New_deaths  \
# 28269    2020-01-03          0                 0           0
# 28270    2020-01-04          0                 0           0
# 28271    2020-01-05          0                 0           0
# 28272    2020-01-06          0                 0           0
# 28273    2020-01-07          0                 0           0
#
#        Cumulative_deaths  intubated
# 28269                  0        NaN
# 28270                  0        NaN
# 28271                  0        NaN
# 28272                  0        NaN
# 28273                  0        NaN

# %% [markdown]
# #### Renaming columns

# %%
df_raw=df_raw.rename(columns={"Cumulative_cases": "Total_cases", "Cumulative_deaths": "Total_deaths"})
df_raw.head()
# Out:
#       Date_reported  New_cases  Total_cases  New_deaths  Total_deaths  \
# 28269    2020-01-03          0            0           0             0
# 28270    2020-01-04          0            0           0             0
# 28271    2020-01-05          0            0           0             0
# 28272    2020-01-06          0            0           0             0
# 28273    2020-01-07          0            0           0             0
#
#        intubated
# 28269        NaN
# 28270        NaN
# 28271        NaN
# 28272        NaN
# 28273        NaN

# %% [markdown]
# #### Sorting the dataframe by Date

# %%
df_raw=df_raw.sort_values(by='Date_reported', ascending=False)
df_raw.head()
# Out:
#       Date_reported  New_cases  Total_cases  New_deaths  Total_deaths  \
# 28632    2020-12-31        942       137918          58          4788
# 28631    2020-12-30       1047       136976          58          4730
# 28630    2020-12-29        476       135931          66          4672
# 28629    2020-12-28        342       135456          53          4606
# 28628    2020-12-27        262       135114          46          4553
#
#        intubated
# 28632      443.0
# 28631      458.0
# 28630      467.0
# 28629      469.0
# 28628      473.0

# %% [markdown]
# #### Converting 'Date_reported' to datetime

# %%
df_raw.Date_reported = pd.to_datetime(df_raw.Date_reported).dt.date

# %%
df_raw.head(10)
# Out:
#       Date_reported  New_cases  Total_cases  New_deaths  Total_deaths  \
# 28632    2020-12-31        942       137918          58          4788
# 28631    2020-12-30       1047       136976          58          4730
# 28630    2020-12-29        476       135931          66          4672
# 28629    2020-12-28        342       135456          53          4606
# 28628    2020-12-27        262       135114          46          4553
# 28627    2020-12-26        617       134852          50          4507
# 28626    2020-12-25        873       134235          55          4442
# 28625    2020-12-24        934       133435          62          4384
# 28624    2020-12-23        853       132501          83          4322
# 28623    2020-12-22        526       131648          85          4239
#
#        intubated
# 28632      443.0
# 28631      458.0
# 28630      467.0
# 28629      469.0
# 28628      473.0
# 28627      470.0
# 28626      476.0
# 28625      495.0
# 28624      491.0
# 28623      505.0

# %% [markdown]
# #### Correcting the deviation of the day

# %%
df_copy = df_raw.copy()
df_copy['Date_reported']=df_copy['Date_reported'].shift(-1)
df_copy.head()
# Out:
#       Date_reported  New_cases  Total_cases  New_deaths  Total_deaths  \
# 28632    2020-12-30        942       137918          58          4788
# 28631    2020-12-29       1047       136976          58          4730
# 28630    2020-12-28        476       135931          66          4672
# 28629    2020-12-27        342       135456          53          4606
# 28628    2020-12-26        262       135114          46          4553
#
#        intubated
# 28632      443.0
# 28631      458.0
# 28630      467.0
# 28629      469.0
# 28628      473.0

# %%
df_copy = df_copy.iloc[:-324]

# %%
df_copy=df_copy.sort_values(by='Total_cases', ascending=True)
df_copy.intubated = df_copy.intubated.astype(int)

# %%
df_copy.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
# #T_82913_row0_col1,#T_82913_row7_col3,#T_82913_row12_col5,#T_82913_row39_col2,#T_82913_row39_col4{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_82913_row0_col2,#T_82913_row0_col4,#T_82913_row35_col1,#T_82913_row35_col3,#T_82913_row39_col5{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }#T_82913_row0_col3,#T_82913_row27_col2{
#             background-color:  #b31218;
#             color:  #f1f1f1;
#         }#T_82913_row0_col5{
#             background-color:  #fb7d5d;
#             color:  #000000;
#         }#T_82913_row1_col1{
#             background-color:  #f14331;
#             color:  #f1f1f1;
#         }#T_82913_row1_col2,#T_82913_row1_col4{
#             background-color:  #fff0e8;
#             color:  #000000;
#         }#T_82913_row1_col3,#T_82913_row17_col5,#T_82913_row24_col2{
#             background-color:  #c8171c;
#             color:  #f1f1f1;
#         }#T_82913_row1_col5,#T_82913_row18_col4{
#             background-color:  #f75b40;
#             color:  #000000;
#         }#T_82913_row2_col1,#T_82913_row14_col1{
#             background-color:  #f6583e;
#             color:  #000000;
#         }#T_82913_row2_col2{
#             background-color:  #ffebe2;
#             color:  #000000;
#         }#T_82913_row2_col3{
#             background-color:  #fa6849;
#             color:  #000000;
#         }#T_82913_row2_col4{
#             background-color:  #ffece3;
#             color:  #000000;
#         }#T_82913_row2_col5{
#             background-color:  #f24734;
#             color:  #000000;
#         }#T_82913_row3_col1,#T_82913_row7_col5,#T_82913_row34_col4{
#             background-color:  #920a13;
#             color:  #f1f1f1;
#         }#T_82913_row3_col2,#T_82913_row37_col1{
#             background-color:  #fee4d8;
#             color:  #000000;
#         }#T_82913_row3_col3,#T_82913_row6_col3,#T_82913_row15_col3,#T_82913_row23_col2{
#             background-color:  #d01d1f;
#             color:  #f1f1f1;
#         }#T_82913_row3_col4{
#             background-color:  #fee7db;
#             color:  #000000;
#         }#T_82913_row3_col5,#T_82913_row27_col3{
#             background-color:  #e32f27;
#             color:  #f1f1f1;
#         }#T_82913_row4_col1,#T_82913_row33_col2{
#             background-color:  #8c0912;
#             color:  #f1f1f1;
#         }#T_82913_row4_col2,#T_82913_row34_col5{
#             background-color:  #fed9c9;
#             color:  #000000;
#         }#T_82913_row4_col3{
#             background-color:  #f7593f;
#             color:  #000000;
#         }#T_82913_row4_col4{
#             background-color:  #fee2d5;
#             color:  #000000;
#         }#T_82913_row4_col5{
#             background-color:  #a91016;
#             color:  #f1f1f1;
#         }#T_82913_row5_col1,#T_82913_row29_col2,#T_82913_row31_col4{
#             background-color:  #aa1016;
#             color:  #f1f1f1;
#         }#T_82913_row5_col2{
#             background-color:  #fdccb8;
#             color:  #000000;
#         }#T_82913_row5_col3,#T_82913_row21_col2{
#             background-color:  #d82422;
#             color:  #f1f1f1;
#         }#T_82913_row5_col4,#T_82913_row36_col5{
#             background-color:  #fedaca;
#             color:  #000000;
#         }#T_82913_row5_col5{
#             background-color:  #8e0912;
#             color:  #f1f1f1;
#         }#T_82913_row6_col1{
#             background-color:  #b01217;
#             color:  #f1f1f1;
#         }#T_82913_row6_col2{
#             background-color:  #fcc1a8;
#             color:  #000000;
#         }#T_82913_row6_col4{
#             background-color:  #fdd1be;
#             color:  #000000;
#         }#T_82913_row6_col5{
#             background-color:  #900a12;
#             color:  #f1f1f1;
#         }#T_82913_row7_col1{
#             background-color:  #d21f20;
#             color:  #f1f1f1;
#         }#T_82913_row7_col2,#T_82913_row9_col4{
#             background-color:  #fcb499;
#             color:  #000000;
#         }#T_82913_row7_col4,#T_82913_row23_col3,#T_82913_row32_col3{
#             background-color:  #fdc6b0;
#             color:  #000000;
#         }#T_82913_row8_col1,#T_82913_row21_col1,#T_82913_row25_col1{
#             background-color:  #fb7858;
#             color:  #000000;
#         }#T_82913_row8_col2,#T_82913_row21_col3{
#             background-color:  #fcad90;
#             color:  #000000;
#         }#T_82913_row8_col3,#T_82913_row13_col3,#T_82913_row14_col3,#T_82913_row24_col3,#T_82913_row24_col4{
#             background-color:  #db2824;
#             color:  #f1f1f1;
#         }#T_82913_row8_col4{
#             background-color:  #fcbda4;
#             color:  #000000;
#         }#T_82913_row8_col5,#T_82913_row33_col4{
#             background-color:  #9c0d14;
#             color:  #f1f1f1;
#         }#T_82913_row9_col1{
#             background-color:  #fc9070;
#             color:  #000000;
#         }#T_82913_row9_col2,#T_82913_row27_col1,#T_82913_row29_col3{
#             background-color:  #fca588;
#             color:  #000000;
#         }#T_82913_row9_col3,#T_82913_row22_col3,#T_82913_row25_col3,#T_82913_row30_col3{
#             background-color:  #f96245;
#             color:  #000000;
#         }#T_82913_row9_col5,#T_82913_row15_col5,#T_82913_row16_col5,#T_82913_row32_col4{
#             background-color:  #a30f15;
#             color:  #f1f1f1;
#         }#T_82913_row10_col1,#T_82913_row36_col2{
#             background-color:  #800610;
#             color:  #f1f1f1;
#         }#T_82913_row10_col2,#T_82913_row12_col4{
#             background-color:  #fc9777;
#             color:  #000000;
#         }#T_82913_row10_col3{
#             background-color:  #a81016;
#             color:  #f1f1f1;
#         }#T_82913_row10_col4{
#             background-color:  #fcaa8d;
#             color:  #000000;
#         }#T_82913_row10_col5{
#             background-color:  #ab1016;
#             color:  #f1f1f1;
#         }#T_82913_row11_col1,#T_82913_row35_col2{
#             background-color:  #840711;
#             color:  #f1f1f1;
#         }#T_82913_row11_col2{
#             background-color:  #fc8767;
#             color:  #000000;
#         }#T_82913_row11_col3,#T_82913_row16_col3{
#             background-color:  #f44f39;
#             color:  #000000;
#         }#T_82913_row11_col4,#T_82913_row32_col1{
#             background-color:  #fca183;
#             color:  #000000;
#         }#T_82913_row11_col5{
#             background-color:  #7e0610;
#             color:  #f1f1f1;
#         }#T_82913_row12_col1{
#             background-color:  #be151a;
#             color:  #f1f1f1;
#         }#T_82913_row12_col2{
#             background-color:  #fb7b5b;
#             color:  #000000;
#         }#T_82913_row12_col3,#T_82913_row22_col2{
#             background-color:  #d32020;
#             color:  #f1f1f1;
#         }#T_82913_row13_col1{
#             background-color:  #e02c26;
#             color:  #f1f1f1;
#         }#T_82913_row13_col2,#T_82913_row16_col1{
#             background-color:  #fb7050;
#             color:  #000000;
#         }#T_82913_row13_col4{
#             background-color:  #fc8d6d;
#             color:  #000000;
#         }#T_82913_row13_col5,#T_82913_row36_col4{
#             background-color:  #820711;
#             color:  #f1f1f1;
#         }#T_82913_row14_col2,#T_82913_row17_col4,#T_82913_row28_col5{
#             background-color:  #fa6648;
#             color:  #000000;
#         }#T_82913_row14_col4{
#             background-color:  #fc8464;
#             color:  #000000;
#         }#T_82913_row14_col5{
#             background-color:  #af1117;
#             color:  #f1f1f1;
#         }#T_82913_row15_col1{
#             background-color:  #fca689;
#             color:  #000000;
#         }#T_82913_row15_col2{
#             background-color:  #f85f43;
#             color:  #000000;
#         }#T_82913_row15_col4{
#             background-color:  #fb7a5a;
#             color:  #000000;
#         }#T_82913_row16_col2{
#             background-color:  #f6553c;
#             color:  #000000;
#         }#T_82913_row16_col4{
#             background-color:  #fb7151;
#             color:  #000000;
#         }#T_82913_row17_col1{
#             background-color:  #f96346;

# %% [markdown]
# # New cases graph<a name="new_cases_graph"></a>

# %%
plt.figure(figsize=(30,12))
plt.title('New cases in Greece (21 November 2020 - today)', fontsize=30)
plt.ylabel('New Cases', fontsize=30)
plt.xlabel('Date', fontsize=30)
plt.xticks(rotation=90)
plt.tick_params(axis='x', labelsize=17)
plt.tick_params(axis='y', labelsize=25)
plt.plot(df_copy['Date_reported'], df_copy['New_cases'])

# %% [markdown]
# # New deaths graph<a name="new_deaths_graph"></a>

# %%
plt.figure(figsize=(30,12))
plt.title('New deaths in Greece (21 November 2020 - today)',fontsize=30)
plt.ylabel('New Deaths',fontsize=30)
plt.xlabel('Date',fontsize=30)
plt.xticks(rotation=90)
plt.tick_params(axis='y', labelsize=25)
plt.tick_params(axis='x', labelsize=18)
plt.plot(df_copy['Date_reported'], df_copy['New_deaths'])

# %% [markdown]
# # Total cases graph<a name="total_cases_graph"></a>

# %%
plt.figure(figsize=(30,12))
plt.title('Total cases in Greece (21 November 2020 - today)',fontsize=30)
plt.ylabel('Total Cases',fontsize=30)
plt.xlabel('Date',fontsize=30)
plt.xticks(rotation=90)
plt.tick_params(axis='x', labelsize=18)
plt.tick_params(axis='y', labelsize=25)
plt.plot(df_copy['Date_reported'], df_copy['Total_cases'])

# %% [markdown]
# # Total deaths graph<a name="total_deaths_graph"></a>

# %%
plt.figure(figsize=(30,12))
plt.title('Total deaths in Greece (21 November 2020 - today)',fontsize=30)
plt.ylabel('Total Deaths',fontsize=30)
plt.xlabel('Date',fontsize=30)
plt.xticks(rotation=90)
plt.tick_params(axis='x', labelsize=18)
plt.tick_params(axis='y', labelsize=25)
plt.plot(df_copy['Date_reported'], df_copy['Total_deaths'])

# %% [markdown]
# # Ιntubated Graph

# %%
plt.figure(figsize=(30,12))
plt.title('Intubated in Greece (21 November 2020 - today)',fontsize=30)
plt.ylabel('Intubated',fontsize=30)
plt.xlabel('Date',fontsize=30)
plt.xticks(rotation=90)
plt.tick_params(axis='x', labelsize=18)
plt.tick_params(axis='y', labelsize=25)
plt.plot(df_copy['Date_reported'], df_copy['intubated'])

# %% [markdown]
# ## Using Prophet to predict covid-19 behavior to 1 week from today

# %%
from fbprophet import Prophet

# %%
new_cases=df_copy.groupby('Date_reported').sum()['New_cases'].reset_index()
new_deaths=df_copy.groupby('Date_reported').sum()['New_deaths'].reset_index()
intubated=df_copy.groupby('Date_reported').sum()['intubated'].reset_index()

# %% [markdown]
# ## Prediction of new deaths <a name="prediction_new_deaths"></a>

# %%
new_deaths.tail(1)[['Date_reported', 'New_deaths']].to_csv(r'C:\Users\Nick\Documents\git\reports\actual_new_deaths_csv' + '\\' + actual_new_deaths_file_name, index = False)
new_deaths.tail()
# Out:
#    Date_reported  New_deaths
# 35    2020-12-26          46
# 36    2020-12-27          53
# 37    2020-12-28          66
# 38    2020-12-29          58
# 39    2020-12-30          58

# %%
new_deaths.columns=['ds','y']

# %%
m=Prophet(interval_width=0.9)
m.fit(new_deaths)
future_new_deaths=m.make_future_dataframe(periods=4)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast_new_deaths=m.predict(future_new_deaths)
forecast_new_deaths.yhat = forecast_new_deaths.yhat.astype(int)
forecast_new_deaths.yhat_lower = forecast_new_deaths.yhat_lower.astype(int)
forecast_new_deaths.yhat_upper = forecast_new_deaths.yhat_upper.astype(int)
forecast_new_deaths[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(4)
# Out:
#            ds  yhat  yhat_lower  yhat_upper
# 40 2020-12-31    55          38          73
# 41 2021-01-01    62          44          79
# 42 2021-01-02    51          33          67
# 43 2021-01-03    53          35          70

# %%
forecast_new_deaths_plot=m.plot(forecast_new_deaths)

# %%
forecast_new_deaths_plot=m.plot_components(forecast_new_deaths)

# %%
forecast_new_deaths.iloc[-4:-3][['ds', 'yhat']].to_csv(r'C:\Users\Nick\Documents\git\reports\predicted_new_deaths_csv' + '\\' + predicted_new_deaths_file_name, index = False)

# %% [markdown]
# ## Prediction of new cases<a name="prediction_new_cases"></a>

# %%
new_cases.tail(1)[['Date_reported', 'New_cases']].to_csv(r'C:\Users\Nick\Documents\git\reports\actual_new_cases_csv' + '\\' + actual_new_cases_file_name, index = False)
new_cases.tail()
# Out:
#    Date_reported  New_cases
# 35    2020-12-26        262
# 36    2020-12-27        342
# 37    2020-12-28        476
# 38    2020-12-29       1047
# 39    2020-12-30        942

# %%
new_cases.columns=['ds','y']

# %%
m=Prophet(interval_width=0.98)
m.fit(new_cases)
future_new_cases=m.make_future_dataframe(periods=4)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast_new_cases=m.predict(future_new_cases)
forecast_new_cases.yhat = forecast_new_cases.yhat.astype(int)
forecast_new_cases.yhat_lower = forecast_new_cases.yhat_lower.astype(int)
forecast_new_cases.yhat_upper = forecast_new_cases.yhat_upper.astype(int)
forecast_new_cases[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(4)
# Out:
#            ds  yhat  yhat_lower  yhat_upper
# 40 2020-12-31   650         262        1062
# 41 2021-01-01   469         120         852
# 42 2021-01-02   317         -62         726
# 43 2021-01-03  -112        -459         247

# %%
forecast_new_cases_plot=m.plot(forecast_new_cases)

# %%
forecast_new_cases_plot=m.plot_components(forecast_new_cases)

# %%
forecast_new_cases.iloc[-4:-3][['ds', 'yhat']].to_csv(r'C:\Users\Nick\Documents\git\reports\predicted_new_cases_csv' + '\\' + predicted_new_cases_file_name, index = False)

# %% [markdown]
# # Predictions of intubated

# %%
intubated.tail(1)[['Date_reported', 'intubated']].to_csv(r'C:\Users\Nick\Documents\git\reports\actual_new_intubated_csv' + '\\' + actual_new_intubated_file_name, index = False)
intubated.tail()
# Out:
#    Date_reported  intubated
# 35    2020-12-26        473
# 36    2020-12-27        469
# 37    2020-12-28        467
# 38    2020-12-29        458
# 39    2020-12-30        443

# %%
intubated.columns=['ds','y']

# %%
m=Prophet(interval_width=0.959)
m.fit(intubated)
future_intubated=m.make_future_dataframe(periods=4)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast_new_intubated=m.predict(future_intubated)
forecast_new_intubated.yhat = forecast_new_intubated.yhat.astype(int)
forecast_new_intubated.yhat_lower = forecast_new_intubated.yhat_lower.astype(int)
forecast_new_intubated.yhat_upper = forecast_new_intubated.yhat_upper.astype(int)
forecast_new_intubated[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(4)
# Out:
#            ds  yhat  yhat_lower  yhat_upper
# 40 2020-12-31   441         426         456
# 41 2021-01-01   432         416         448
# 42 2021-01-02   424         408         439
# 43 2021-01-03   414         398         432

# %%
forecast_new_intubated_plot=m.plot(forecast_new_intubated)

# %%
forecast_new_intubated_plot=m.plot_components(forecast_new_intubated)

# %%
forecast_new_intubated.iloc[-4:-3][['ds', 'yhat']].to_csv(r'C:\Users\Nick\Documents\git\reports\predicted_new_intubated_csv' + '\\' + predicted_new_intubated_file_name, index = False)
