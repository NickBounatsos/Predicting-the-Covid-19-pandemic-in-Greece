# %% [markdown]
# # Covid-19 Overview in Greece

# %% [markdown]
# ## Table of contents
# * [Introduction](#introduction)
# * [Data](#data)
# * [New cases graph](#new_cases_graph)
# * [New deaths graph](#new_deaths_graph)
# * [Total cases graph](#total_cases_graph)
# * [Total deaths graph](#total_deaths_graph)
# * [Prediction of total cases](#prediction_total_cases)
# * [Prediction of total deaths](#prediction_total_deaths)
# * [Prediction of new deaths](#prediction_new_deaths)
# * [Prediction of new cases](#prediction_new_cases)

# %% [markdown]
# # Introduction <a name="introduction"></a>

# %% [markdown]
# ## Data <a name="data"></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from matplotlib.ticker import StrMethodFormatter
import seaborn as sns
import scipy
import plotly
import folium
from folium import plugins
import statsmodels.formula.api as smf
import statsmodels.api as sm
from sklearn import model_selection, preprocessing, feature_selection, ensemble, linear_model, metrics, decomposition
from lime import lime_tabular
import plotly.express as px
import plotly.graph_objects as go
import os

# %%
# !wget -nv https://covid19.who.int/WHO-COVID-19-global-data.csv
print('File downloaded!')
file_name=('WHO-COVID-19-global-data.csv')
df_raw=pd.read_csv(file_name)
print('File copied to DataFrame!')
os.remove("WHO-COVID-19-global-data.csv")
print("File Removed!")
# Out:
# File downloaded!
# File copied to DataFrame!
# File Removed!
# 2020-12-11 23:11:11 URL:https://covid19.who.int/WHO-COVID-19-global-data.csv [3449331/3449331] -> "WHO-COVID-19-global-data.csv" [1]

# %%
df_raw.head()
# Out:
#   Date_reported Country_code      Country WHO_region  New_cases  \
# 0    2020-01-03           AF  Afghanistan       EMRO          0
# 1    2020-01-04           AF  Afghanistan       EMRO          0
# 2    2020-01-05           AF  Afghanistan       EMRO          0
# 3    2020-01-06           AF  Afghanistan       EMRO          0
# 4    2020-01-07           AF  Afghanistan       EMRO          0
#
#    Cumulative_cases  New_deaths  Cumulative_deaths
# 0                 0           0                  0
# 1                 0           0                  0
# 2                 0           0                  0
# 3                 0           0                  0
# 4                 0           0                  0

# %% [markdown]
# #### Removing data from all the countries except Greece

# %%
df_raw=df_raw[df_raw['Country'].str.contains('Greece')]
df_raw.head()
# Out:
#       Date_reported Country_code Country WHO_region  New_cases  \
# 27864    2020-01-03           GR  Greece       EURO          0
# 27865    2020-01-04           GR  Greece       EURO          0
# 27866    2020-01-05           GR  Greece       EURO          0
# 27867    2020-01-06           GR  Greece       EURO          0
# 27868    2020-01-07           GR  Greece       EURO          0
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 27864                 0           0                  0
# 27865                 0           0                  0
# 27866                 0           0                  0
# 27867                 0           0                  0
# 27868                 0           0                  0

# %% [markdown]
# #### Removing unnecessary data columns

# %%
df_raw=df_raw.drop(columns=["Country_code", "WHO_region", "Country"])
df_raw.head()
# Out:
#       Date_reported  New_cases  Cumulative_cases  New_deaths  \
# 27864    2020-01-03          0                 0           0
# 27865    2020-01-04          0                 0           0
# 27866    2020-01-05          0                 0           0
# 27867    2020-01-06          0                 0           0
# 27868    2020-01-07          0                 0           0
#
#        Cumulative_deaths
# 27864                  0
# 27865                  0
# 27866                  0
# 27867                  0
# 27868                  0

# %% [markdown]
# #### Renaming columns

# %%
df_raw=df_raw.rename(columns={"Cumulative_cases": "Total_cases", "Cumulative_deaths": "Total_deaths"})
df_raw.head()
# Out:
#       Date_reported  New_cases  Total_cases  New_deaths  Total_deaths
# 27864    2020-01-03          0            0           0             0
# 27865    2020-01-04          0            0           0             0
# 27866    2020-01-05          0            0           0             0
# 27867    2020-01-06          0            0           0             0
# 27868    2020-01-07          0            0           0             0

# %% [markdown]
# #### Sorting the dataframe by Date

# %%
df_raw=df_raw.sort_values(by='Date_reported', ascending=False)
df_raw.head()
# Out:
#       Date_reported  New_cases  Total_cases  New_deaths  Total_deaths
# 28207    2020-12-11       1533       121253          81          3370
# 28206    2020-12-10       1675       119720          95          3289
# 28205    2020-12-09       1324       118045         102          3194
# 28204    2020-12-08       1250       116721          89          3092
# 28203    2020-12-07        903       115471         101          3003

# %% [markdown]
# #### Converting 'Date_reported' to datetime

# %%
df_raw.Date_reported = pd.to_datetime(df_raw.Date_reported).dt.date

# %%
df_raw.head(10)
# Out:
#       Date_reported  New_cases  Total_cases  New_deaths  Total_deaths
# 28207    2020-12-11       1533       121253          81          3370
# 28206    2020-12-10       1675       119720          95          3289
# 28205    2020-12-09       1324       118045         102          3194
# 28204    2020-12-08       1250       116721          89          3092
# 28203    2020-12-07        903       115471         101          3003
# 28202    2020-12-06       1383       114568          98          2902
# 28201    2020-12-05       1648       113185          98          2804
# 28200    2020-12-04       1882       111537         100          2706
# 28199    2020-12-03       2185       109655          89          2606
# 28198    2020-12-02       2199       107470         111          2517

# %% [markdown]
# #### Correcting the deviation of the day

# %%
df_copy = df_raw.copy()
df_copy['Date_reported']=df_copy['Date_reported'].shift(-1)
df_copy.head()
# Out:
#       Date_reported  New_cases  Total_cases  New_deaths  Total_deaths
# 28207    2020-12-10       1533       121253          81          3370
# 28206    2020-12-09       1675       119720          95          3289
# 28205    2020-12-08       1324       118045         102          3194
# 28204    2020-12-07       1250       116721          89          3092
# 28203    2020-12-06        903       115471         101          3003

# %%
df_copy = df_copy.iloc[:-310]

# %%
df_copy=df_copy.sort_values(by='Total_cases', ascending=True)

# %%
df_copy.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
# #T_65836d3f_3bf5_11eb_9bf4_309c2382d253row0_col1{
#             background-color:  #dd2a25;
#             color:  #f1f1f1;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row0_col2,#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row0_col3,#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row0_col4,#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row29_col1{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row1_col1,#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row11_col2,#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row17_col4{
#             background-color:  #fc8767;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row1_col2,#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row2_col4{
#             background-color:  #fff0e9;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row1_col3{
#             background-color:  #fff4ee;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row1_col4{
#             background-color:  #fff3ed;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row2_col1{
#             background-color:  #fcbda4;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row2_col2{
#             background-color:  #ffece4;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row2_col3,#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row3_col3,#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row5_col4{
#             background-color:  #fee8dd;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row3_col1{
#             background-color:  #f03f2e;
#             color:  #f1f1f1;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row3_col2{
#             background-color:  #fee7db;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row3_col4,#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row6_col3,#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row7_col3{
#             background-color:  #ffeee6;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row4_col1{
#             background-color:  #c5171c;
#             color:  #f1f1f1;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row4_col2{
#             background-color:  #fee0d2;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row4_col3{
#             background-color:  #fee4d8;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row4_col4{
#             background-color:  #ffebe2;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row5_col1,#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row21_col3,#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row33_col2,#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row33_col4{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row5_col2{
#             background-color:  #fdd1be;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row5_col3{
#             background-color:  #fdcebb;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row6_col1,#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row24_col3{
#             background-color:  #9f0e14;
#             color:  #f1f1f1;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row6_col2{
#             background-color:  #fcc3ab;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row6_col4{
#             background-color:  #fee5d9;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row7_col1{
#             background-color:  #bc141a;
#             color:  #f1f1f1;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row7_col2{
#             background-color:  #fcb69b;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row7_col4{
#             background-color:  #fee3d7;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row8_col1{
#             background-color:  #fca183;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row8_col2{
#             background-color:  #fcae92;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row8_col3{
#             background-color:  #fc8262;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row8_col4{
#             background-color:  #fedecf;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row9_col1,#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row24_col1{
#             background-color:  #f75c41;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row9_col2{
#             background-color:  #fca285;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row9_col3,#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row12_col3{
#             background-color:  #fcaf93;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row9_col4{
#             background-color:  #fdd7c6;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row10_col1,#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row23_col4,#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row25_col3,#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row30_col3{
#             background-color:  #ed392b;
#             color:  #f1f1f1;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row10_col2{
#             background-color:  #fc9777;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row10_col3{
#             background-color:  #fca082;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row10_col4{
#             background-color:  #fdd0bc;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row11_col1{
#             background-color:  #7c0510;
#             color:  #f1f1f1;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row11_col3{
#             background-color:  #fcab8f;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row11_col4{
#             background-color:  #fdc9b3;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row12_col1{
#             background-color:  #79040f;
#             color:  #f1f1f1;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row12_col2{
#             background-color:  #fb7757;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row12_col4{
#             background-color:  #fcc2aa;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row13_col1{
#             background-color:  #de2b25;
#             color:  #f1f1f1;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row13_col2{
#             background-color:  #fb6b4b;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row13_col3{
#             background-color:  #fc7f5f;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row13_col4{
#             background-color:  #fcb99f;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row14_col1{
#             background-color:  #f34a36;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row14_col2,#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row25_col1{
#             background-color:  #f85d42;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row14_col3{
#             background-color:  #ac1117;
#             color:  #f1f1f1;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row14_col4{
#             background-color:  #fcad90;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row15_col1{
#             background-color:  #fcbca2;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row15_col2{
#             background-color:  #f6563d;
#             color:  #000000;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row15_col3{
#             background-color:  #bd151a;
#             color:  #f1f1f1;
#         }#T_65836d3f_3bf5_11eb_9bf4_309c2382d253row15_col

# %% [markdown]
# # New cases graph<a name="new_cases_graph"></a>

# %%
plt.figure(figsize=(30,12))
plt.title('New cases in Greece (7 November 2020 - today)', fontsize=30)
plt.ylabel('New Cases', fontsize=30)
plt.xlabel('Date', fontsize=30)
plt.xticks(rotation=90)
plt.tick_params(axis='x', labelsize=17)
plt.tick_params(axis='y', labelsize=25)
plt.plot(df_copy['Date_reported'], df_copy['New_cases'])

# %% [markdown]
# # New deaths graph<a name="new_deaths_graph"></a>

# %%
plt.figure(figsize=(30,12))
plt.title('New deaths in Greece (7 November 2020 - today)',fontsize=30)
plt.ylabel('New Deaths',fontsize=30)
plt.xlabel('Date',fontsize=30)
plt.xticks(rotation=90)
plt.tick_params(axis='y', labelsize=25)
plt.tick_params(axis='x', labelsize=18)
plt.plot(df_copy['Date_reported'], df_copy['New_deaths'])

# %% [markdown]
# # Total cases graph<a name="total_cases_graph"></a>

# %%
plt.figure(figsize=(30,12))
plt.title('Total cases in Greece (7 November 2020 - today)',fontsize=30)
plt.ylabel('Total Cases',fontsize=30)
plt.xlabel('Date',fontsize=30)
plt.xticks(rotation=90)
plt.tick_params(axis='x', labelsize=18)
plt.tick_params(axis='y', labelsize=25)
plt.plot(df_copy['Date_reported'], df_copy['Total_cases'])

# %% [markdown]
# # Total deaths graph<a name="total_deaths_graph"></a>

# %%
plt.figure(figsize=(30,12))
plt.title('Total deaths in Greece (7 November 2020 - today)',fontsize=30)
plt.ylabel('Total Deaths',fontsize=30)
plt.xlabel('Date',fontsize=30)
plt.xticks(rotation=90)
plt.tick_params(axis='x', labelsize=18)
plt.tick_params(axis='y', labelsize=25)
plt.plot(df_copy['Date_reported'], df_copy['Total_deaths'])

# %% [markdown]
# ## Using Prophet to predict covid-19 behavior to 1 week from today

# %%
from fbprophet import Prophet

# %%
new_cases=df_copy.groupby('Date_reported').sum()['New_cases'].reset_index()
new_deaths=df_copy.groupby('Date_reported').sum()['New_deaths'].reset_index()
total_cases=df_copy.groupby('Date_reported').sum()['Total_cases'].reset_index()
total_deaths=df_copy.groupby('Date_reported').sum()['Total_deaths'].reset_index()

# %% [markdown]
# ## Prediction of Total Cases<a name="prediction_total_cases"></a>

# %%
total_cases.tail()
# Out:
#    Date_reported  Total_cases
# 29    2020-12-06       115471
# 30    2020-12-07       116721
# 31    2020-12-08       118045
# 32    2020-12-09       119720
# 33    2020-12-10       121253

# %%
total_cases.columns=['ds','y']

# %%
m=Prophet(interval_width=0.95)
m.fit(total_cases)
future_total_cases=m.make_future_dataframe(periods=4)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast_total_cases=m.predict(future_total_cases)
forecast_total_cases[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(4)
# Out:
#            ds           yhat     yhat_lower     yhat_upper
# 34 2020-12-11  122895.255234  122290.528775  123454.569307
# 35 2020-12-12  124284.049338  122657.277967  125807.154276
# 36 2020-12-13  125185.148702  122352.310232  128117.087684
# 37 2020-12-14  126435.042738  122224.529637  130973.389284

# %%
forecast_total_cases_plot=m.plot(forecast_total_cases)

# %%
forecast_total_cases_plot=m.plot_components(forecast_total_cases)

# %% [markdown]
# ## Prediction of total deaths<a name="prediction_total_deaths"></a>

# %%
total_deaths.tail()
# Out:
#    Date_reported  Total_deaths
# 29    2020-12-06          3003
# 30    2020-12-07          3092
# 31    2020-12-08          3194
# 32    2020-12-09          3289
# 33    2020-12-10          3370

# %%
total_deaths.columns=['ds','y']

# %%
m=Prophet(interval_width=0.95)
m.fit(total_deaths)
future_total_deaths=m.make_future_dataframe(periods=4)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast_total_deaths=m.predict(future_total_deaths)
forecast_total_deaths[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(4)
# Out:
#            ds         yhat   yhat_lower   yhat_upper
# 34 2020-12-11  3467.222009  3458.440693  3475.602172
# 35 2020-12-12  3573.718143  3554.282004  3589.390368
# 36 2020-12-13  3673.424410  3638.380650  3704.032838
# 37 2020-12-14  3762.182048  3711.578800  3810.479066

# %%
forecast_total_deaths_plot=m.plot(forecast_total_deaths)

# %%
forecast_total_deaths_plot=m.plot_components(forecast_total_deaths)

# %% [markdown]
# ## Prediction of new deaths <a name="prediction_new_deaths"></a>

# %%
new_deaths.tail()
# Out:
#    Date_reported  New_deaths
# 29    2020-12-06         101
# 30    2020-12-07          89
# 31    2020-12-08         102
# 32    2020-12-09          95
# 33    2020-12-10          81

# %%
new_deaths.columns=['ds','y']

# %%
m=Prophet(interval_width=0.95)
m.fit(new_deaths)
future_new_deaths=m.make_future_dataframe(periods=4)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast_new_deaths=m.predict(future_new_deaths)
forecast_new_deaths[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(4)
# Out:
#            ds        yhat  yhat_lower  yhat_upper
# 34 2020-12-11  115.742321   88.096281  141.767216
# 35 2020-12-12  126.004115   98.164166  153.976088
# 36 2020-12-13  127.799113  101.079372  154.171758
# 37 2020-12-14  117.796534   89.849914  143.877523

# %%
forecast_new_deaths_plot=m.plot(forecast_new_deaths)

# %%
forecast_new_deaths_plot=m.plot_components(forecast_new_deaths)

# %% [markdown]
# ## Prediction of new cases<a name="prediction_new_cases"></a>

# %%
new_cases.tail()
# Out:
#    Date_reported  New_cases
# 29    2020-12-06        903
# 30    2020-12-07       1250
# 31    2020-12-08       1324
# 32    2020-12-09       1675
# 33    2020-12-10       1533

# %%
new_cases.columns=['ds','y']

# %%
m=Prophet(interval_width=0.95)
m.fit(new_cases)
future_new_cases=m.make_future_dataframe(periods=4)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast_new_cases=m.predict(future_new_cases)
forecast_new_cases[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(4)
# Out:
#            ds         yhat   yhat_lower   yhat_upper
# 34 2020-12-11  1522.181707  1016.390652  2038.798435
# 35 2020-12-12  1227.285773   724.353580  1784.682523
# 36 2020-12-13   497.328624   -18.073302  1005.901010
# 37 2020-12-14   535.253277    -8.746472  1053.091545

# %%
forecast_new_cases_plot=m.plot(forecast_new_cases)

# %%
forecast_new_cases_plot=m.plot_components(forecast_new_cases)
