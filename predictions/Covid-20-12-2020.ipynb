# %% [markdown]
# # Covid-19 Overview in Greece

# %% [markdown]
# ## Table of contents
# * [Introduction](#introduction)
# * [Data](#data)
# * [New cases graph](#new_cases_graph)
# * [New deaths graph](#new_deaths_graph)
# * [Total cases graph](#total_cases_graph)
# * [Total deaths graph](#total_deaths_graph)
# * [Prediction of total cases](#prediction_total_cases)
# * [Prediction of total deaths](#prediction_total_deaths)
# * [Prediction of new deaths](#prediction_new_deaths)
# * [Prediction of new cases](#prediction_new_cases)

# %% [markdown]
# # Introduction <a name="introduction"></a>

# %% [markdown]
# ## Data <a name="data"></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from matplotlib.ticker import StrMethodFormatter
import seaborn as sns
import scipy
import plotly
import folium
from folium import plugins
import statsmodels.formula.api as smf
import statsmodels.api as sm
from sklearn import model_selection, preprocessing, feature_selection, ensemble, linear_model, metrics, decomposition
from lime import lime_tabular
import plotly.express as px
import plotly.graph_objects as go
import os

# %%
#!wget -nv https://covid19.who.int/WHO-COVID-19-global-data.csv
#print('File downloaded!')
file_name=('cov.csv')
df_raw=pd.read_csv(file_name)
print('File copied to DataFrame!')
#os.remove("WHO-COVID-19-global-data.csv")
#print("File Removed!")
# Out:
# File copied to DataFrame!

# %%
df_raw.head()
# Out:
#   Date_reported Country_code      Country WHO_region  New_cases  \
# 0    2020-01-03           AF  Afghanistan       EMRO          0
# 1    2020-01-04           AF  Afghanistan       EMRO          0
# 2    2020-01-05           AF  Afghanistan       EMRO          0
# 3    2020-01-06           AF  Afghanistan       EMRO          0
# 4    2020-01-07           AF  Afghanistan       EMRO          0
#
#    Cumulative_cases  New_deaths  Cumulative_deaths
# 0                 0           0                  0
# 1                 0           0                  0
# 2                 0           0                  0
# 3                 0           0                  0
# 4                 0           0                  0

# %% [markdown]
# #### Removing data from all the countries except Greece

# %%
df_raw=df_raw[df_raw['Country'].str.contains('Greece')]
df_raw.head()
# Out:
#       Date_reported Country_code Country WHO_region  New_cases  \
# 28269    2020-01-03           GR  Greece       EURO          0
# 28270    2020-01-04           GR  Greece       EURO          0
# 28271    2020-01-05           GR  Greece       EURO          0
# 28272    2020-01-06           GR  Greece       EURO          0
# 28273    2020-01-07           GR  Greece       EURO          0
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 28269                 0           0                  0
# 28270                 0           0                  0
# 28271                 0           0                  0
# 28272                 0           0                  0
# 28273                 0           0                  0

# %% [markdown]
# #### Removing unnecessary data columns

# %%
df_raw=df_raw.drop(columns=["Country_code", "WHO_region", "Country"])
df_raw.head()
# Out:
#       Date_reported  New_cases  Cumulative_cases  New_deaths  \
# 28269    2020-01-03          0                 0           0
# 28270    2020-01-04          0                 0           0
# 28271    2020-01-05          0                 0           0
# 28272    2020-01-06          0                 0           0
# 28273    2020-01-07          0                 0           0
#
#        Cumulative_deaths
# 28269                  0
# 28270                  0
# 28271                  0
# 28272                  0
# 28273                  0

# %% [markdown]
# #### Renaming columns

# %%
df_raw=df_raw.rename(columns={"Cumulative_cases": "Total_cases", "Cumulative_deaths": "Total_deaths"})
df_raw.head()
# Out:
#       Date_reported  New_cases  Total_cases  New_deaths  Total_deaths
# 28269    2020-01-03          0            0           0             0
# 28270    2020-01-04          0            0           0             0
# 28271    2020-01-05          0            0           0             0
# 28272    2020-01-06          0            0           0             0
# 28273    2020-01-07          0            0           0             0

# %% [markdown]
# #### Sorting the dataframe by Date

# %%
df_raw=df_raw.sort_values(by='Date_reported', ascending=False)
df_raw.head()
# Out:
#       Date_reported  New_cases  Total_cases  New_deaths  Total_deaths
# 28622    2020-12-21        588       131122          70          4154
# 28621    2020-12-20        901       130534          58          4084
# 28620    2020-12-19        916       129633          96          4026
# 28619    2020-12-18       1155       128717          78          3948
# 28618    2020-12-17       1190       127562          85          3870

# %% [markdown]
# #### Converting 'Date_reported' to datetime

# %%
df_raw.Date_reported = pd.to_datetime(df_raw.Date_reported).dt.date

# %%
df_raw.head(10)
# Out:
#       Date_reported  New_cases  Total_cases  New_deaths  Total_deaths
# 28622    2020-12-21        588       131122          70          4154
# 28621    2020-12-20        901       130534          58          4084
# 28620    2020-12-19        916       129633          96          4026
# 28619    2020-12-18       1155       128717          78          3948
# 28618    2020-12-17       1190       127562          85          3870
# 28617    2020-12-16       1199       126372          98          3785
# 28616    2020-12-15        639       125173          62          3687
# 28615    2020-12-14        692       124534          85          3625
# 28614    2020-12-13       1194       123842          68          3540
# 28613    2020-12-12       1395       122648         102          3472

# %% [markdown]
# #### Correcting the deviation of the day

# %%
df_copy = df_raw.copy()
df_copy['Date_reported']=df_copy['Date_reported'].shift(-1)
df_copy.head()
# Out:
#       Date_reported  New_cases  Total_cases  New_deaths  Total_deaths
# 28622    2020-12-20        588       131122          70          4154
# 28621    2020-12-19        901       130534          58          4084
# 28620    2020-12-18        916       129633          96          4026
# 28619    2020-12-17       1155       128717          78          3948
# 28618    2020-12-16       1190       127562          85          3870

# %%
df_copy = df_copy.iloc[:-324]

# %%
df_copy=df_copy.sort_values(by='Total_cases', ascending=True)

# %%
df_copy.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
# #T_dbfcbb1d_437d_11eb_b849_309c2382d253row0_col1,#T_dbfcbb1d_437d_11eb_b849_309c2382d253row7_col3,#T_dbfcbb1d_437d_11eb_b849_309c2382d253row29_col2,#T_dbfcbb1d_437d_11eb_b849_309c2382d253row29_col4{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row0_col2,#T_dbfcbb1d_437d_11eb_b849_309c2382d253row0_col4,#T_dbfcbb1d_437d_11eb_b849_309c2382d253row28_col3,#T_dbfcbb1d_437d_11eb_b849_309c2382d253row29_col1{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row0_col3,#T_dbfcbb1d_437d_11eb_b849_309c2382d253row20_col2{
#             background-color:  #bd151a;
#             color:  #f1f1f1;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row1_col1{
#             background-color:  #f85f43;
#             color:  #000000;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row1_col2{
#             background-color:  #ffefe8;
#             color:  #000000;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row1_col3{
#             background-color:  #d52221;
#             color:  #f1f1f1;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row1_col4{
#             background-color:  #ffeee7;
#             color:  #000000;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row2_col1,#T_dbfcbb1d_437d_11eb_b849_309c2382d253row14_col1{
#             background-color:  #fb7656;
#             color:  #000000;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row2_col2,#T_dbfcbb1d_437d_11eb_b849_309c2382d253row2_col4{
#             background-color:  #fee9df;
#             color:  #000000;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row2_col3,#T_dbfcbb1d_437d_11eb_b849_309c2382d253row11_col4{
#             background-color:  #fc8666;
#             color:  #000000;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row3_col1{
#             background-color:  #9a0c14;
#             color:  #f1f1f1;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row3_col2{
#             background-color:  #fee1d3;
#             color:  #000000;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row3_col3,#T_dbfcbb1d_437d_11eb_b849_309c2382d253row6_col3,#T_dbfcbb1d_437d_11eb_b849_309c2382d253row15_col3,#T_dbfcbb1d_437d_11eb_b849_309c2382d253row17_col2{
#             background-color:  #de2b25;
#             color:  #f1f1f1;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row3_col4{
#             background-color:  #fee3d6;
#             color:  #000000;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row4_col1{
#             background-color:  #940b13;
#             color:  #f1f1f1;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row4_col2{
#             background-color:  #fdd2bf;
#             color:  #000000;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row4_col3{
#             background-color:  #fb7757;
#             color:  #000000;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row4_col4{
#             background-color:  #fedbcc;
#             color:  #000000;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row5_col1{
#             background-color:  #b21218;
#             color:  #f1f1f1;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row5_col2{
#             background-color:  #fcc3ab;
#             color:  #000000;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row5_col3,#T_dbfcbb1d_437d_11eb_b849_309c2382d253row16_col2{
#             background-color:  #e83429;
#             color:  #f1f1f1;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row5_col4,#T_dbfcbb1d_437d_11eb_b849_309c2382d253row15_col1,#T_dbfcbb1d_437d_11eb_b849_309c2382d253row28_col1{
#             background-color:  #fdd0bc;
#             color:  #000000;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row6_col1{
#             background-color:  #b81419;
#             color:  #f1f1f1;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row6_col2{
#             background-color:  #fcb499;
#             color:  #000000;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row6_col4{
#             background-color:  #fcc4ad;
#             color:  #000000;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row7_col1{
#             background-color:  #e12d26;
#             color:  #f1f1f1;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row7_col2{
#             background-color:  #fca689;
#             color:  #000000;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row7_col4,#T_dbfcbb1d_437d_11eb_b849_309c2382d253row9_col1{
#             background-color:  #fcb79c;
#             color:  #000000;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row8_col1,#T_dbfcbb1d_437d_11eb_b849_309c2382d253row25_col1{
#             background-color:  #fc9b7c;
#             color:  #000000;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row8_col2{
#             background-color:  #fc9c7d;
#             color:  #000000;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row8_col3,#T_dbfcbb1d_437d_11eb_b849_309c2382d253row13_col3,#T_dbfcbb1d_437d_11eb_b849_309c2382d253row14_col3,#T_dbfcbb1d_437d_11eb_b849_309c2382d253row17_col4,#T_dbfcbb1d_437d_11eb_b849_309c2382d253row24_col3{
#             background-color:  #ec382b;
#             color:  #f1f1f1;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row8_col4{
#             background-color:  #fcaa8d;
#             color:  #000000;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row9_col2{
#             background-color:  #fc9474;
#             color:  #000000;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row9_col3,#T_dbfcbb1d_437d_11eb_b849_309c2382d253row17_col1,#T_dbfcbb1d_437d_11eb_b849_309c2382d253row22_col3,#T_dbfcbb1d_437d_11eb_b849_309c2382d253row25_col3{
#             background-color:  #fc8161;
#             color:  #000000;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row9_col4{
#             background-color:  #fca082;
#             color:  #000000;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row10_col1{
#             background-color:  #860811;
#             color:  #f1f1f1;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row10_col2{
#             background-color:  #fc8262;
#             color:  #000000;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row10_col3{
#             background-color:  #af1117;
#             color:  #f1f1f1;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row10_col4{
#             background-color:  #fc9272;
#             color:  #000000;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row11_col1{
#             background-color:  #8a0812;
#             color:  #f1f1f1;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row11_col2{
#             background-color:  #fb7252;
#             color:  #000000;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row11_col3,#T_dbfcbb1d_437d_11eb_b849_309c2382d253row16_col3{
#             background-color:  #fb6d4d;
#             color:  #000000;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row12_col1{
#             background-color:  #ca181d;
#             color:  #f1f1f1;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row12_col2,#T_dbfcbb1d_437d_11eb_b849_309c2382d253row14_col4{
#             background-color:  #f96245;
#             color:  #000000;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row12_col3{
#             background-color:  #e32f27;
#             color:  #f1f1f1;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row12_col4{
#             background-color:  #fb7b5b;
#             color:  #000000;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row13_col1{
#             background-color:  #f03f2e;
#             color:  #f1f1f1;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row13_col2{
#             background-color:  #f5523a;
#             color:  #000000;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row13_col4{
#             background-color:  #fb6e4e;
#             color:  #000000;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row14_col2,#T_dbfcbb1d_437d_11eb_b849_309c2382d253row16_col4{
#             background-color:  #f24633;
#             color:  #000000;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382d253row15_col2{
#             background-color:  #f03d2d;
#             color:  #f1f1f1;
#         }#T_dbfcbb1d_437d_11eb_b849_309c2382

# %% [markdown]
# # New cases graph<a name="new_cases_graph"></a>

# %%
plt.figure(figsize=(30,12))
plt.title('New cases in Greece (7 November 2020 - today)', fontsize=30)
plt.ylabel('New Cases', fontsize=30)
plt.xlabel('Date', fontsize=30)
plt.xticks(rotation=90)
plt.tick_params(axis='x', labelsize=17)
plt.tick_params(axis='y', labelsize=25)
plt.plot(df_copy['Date_reported'], df_copy['New_cases'])

# %% [markdown]
# # New deaths graph<a name="new_deaths_graph"></a>

# %%
plt.figure(figsize=(30,12))
plt.title('New deaths in Greece (7 November 2020 - today)',fontsize=30)
plt.ylabel('New Deaths',fontsize=30)
plt.xlabel('Date',fontsize=30)
plt.xticks(rotation=90)
plt.tick_params(axis='y', labelsize=25)
plt.tick_params(axis='x', labelsize=18)
plt.plot(df_copy['Date_reported'], df_copy['New_deaths'])

# %% [markdown]
# # Total cases graph<a name="total_cases_graph"></a>

# %%
plt.figure(figsize=(30,12))
plt.title('Total cases in Greece (7 November 2020 - today)',fontsize=30)
plt.ylabel('Total Cases',fontsize=30)
plt.xlabel('Date',fontsize=30)
plt.xticks(rotation=90)
plt.tick_params(axis='x', labelsize=18)
plt.tick_params(axis='y', labelsize=25)
plt.plot(df_copy['Date_reported'], df_copy['Total_cases'])

# %% [markdown]
# # Total deaths graph<a name="total_deaths_graph"></a>

# %%
plt.figure(figsize=(30,12))
plt.title('Total deaths in Greece (7 November 2020 - today)',fontsize=30)
plt.ylabel('Total Deaths',fontsize=30)
plt.xlabel('Date',fontsize=30)
plt.xticks(rotation=90)
plt.tick_params(axis='x', labelsize=18)
plt.tick_params(axis='y', labelsize=25)
plt.plot(df_copy['Date_reported'], df_copy['Total_deaths'])

# %% [markdown]
# ## Using Prophet to predict covid-19 behavior to 1 week from today

# %%
from fbprophet import Prophet

# %%
new_cases=df_copy.groupby('Date_reported').sum()['New_cases'].reset_index()
new_deaths=df_copy.groupby('Date_reported').sum()['New_deaths'].reset_index()
total_cases=df_copy.groupby('Date_reported').sum()['Total_cases'].reset_index()
total_deaths=df_copy.groupby('Date_reported').sum()['Total_deaths'].reset_index()

# %% [markdown]
# ## Prediction of Total Cases<a name="prediction_total_cases"></a>

# %%
total_cases.tail()
# Out:
#    Date_reported  Total_cases
# 25    2020-12-16       127562
# 26    2020-12-17       128717
# 27    2020-12-18       129633
# 28    2020-12-19       130534
# 29    2020-12-20       131122

# %%
total_cases.columns=['ds','y']

# %%
m=Prophet(interval_width=0.95)
m.fit(total_cases)
future_total_cases=m.make_future_dataframe(periods=4)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 23.

# %%
forecast_total_cases=m.predict(future_total_cases)
forecast_total_cases[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(4)
# Out:
#            ds           yhat     yhat_lower     yhat_upper
# 30 2020-12-21  131599.818904  131266.256220  131844.049741
# 31 2020-12-22  132798.818904  131982.619443  133521.780430
# 32 2020-12-23  133988.818904  132498.478450  135287.591392
# 33 2020-12-24  135143.818904  132872.607992  137184.094276

# %%
forecast_total_cases_plot=m.plot(forecast_total_cases)

# %%
forecast_total_cases_plot=m.plot_components(forecast_total_cases)

# %% [markdown]
# ## Prediction of total deaths<a name="prediction_total_deaths"></a>

# %%
total_deaths.tail()
# Out:
#    Date_reported  Total_deaths
# 25    2020-12-16          3870
# 26    2020-12-17          3948
# 27    2020-12-18          4026
# 28    2020-12-19          4084
# 29    2020-12-20          4154

# %%
total_deaths.columns=['ds','y']

# %%
m=Prophet(interval_width=0.95)
m.fit(total_deaths)
future_total_deaths=m.make_future_dataframe(periods=4)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 23.

# %%
forecast_total_deaths=m.predict(future_total_deaths)
forecast_total_deaths[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(4)
# Out:
#            ds         yhat   yhat_lower   yhat_upper
# 30 2020-12-21  4209.311282  4189.777422  4226.530416
# 31 2020-12-22  4307.311282  4249.840519  4362.785688
# 32 2020-12-23  4392.311282  4287.767711  4490.132797
# 33 2020-12-24  4470.311282  4311.021324  4615.289020

# %%
forecast_total_deaths_plot=m.plot(forecast_total_deaths)

# %%
forecast_total_deaths_plot=m.plot_components(forecast_total_deaths)

# %% [markdown]
# ## Prediction of new deaths <a name="prediction_new_deaths"></a>

# %%
new_deaths.tail()
# Out:
#    Date_reported  New_deaths
# 25    2020-12-16          85
# 26    2020-12-17          78
# 27    2020-12-18          96
# 28    2020-12-19          58
# 29    2020-12-20          70

# %%
new_deaths.columns=['ds','y']

# %%
m=Prophet(interval_width=0.95)
m.fit(new_deaths)
future_new_deaths=m.make_future_dataframe(periods=4)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 23.

# %%
forecast_new_deaths=m.predict(future_new_deaths)
forecast_new_deaths[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(4)
# Out:
#            ds       yhat  yhat_lower  yhat_upper
# 30 2020-12-21  62.302221   44.069128   80.131419
# 31 2020-12-22  85.334528   67.691348  101.760674
# 32 2020-12-23  71.317073   54.159945   88.701685
# 33 2020-12-24  71.819255   54.207814   88.905646

# %%
forecast_new_deaths_plot=m.plot(forecast_new_deaths)

# %%
forecast_new_deaths_plot=m.plot_components(forecast_new_deaths)

# %% [markdown]
# ## Prediction of new cases<a name="prediction_new_cases"></a>

# %%
new_cases.tail()
# Out:
#    Date_reported  New_cases
# 25    2020-12-16       1190
# 26    2020-12-17       1155
# 27    2020-12-18        916
# 28    2020-12-19        901
# 29    2020-12-20        588

# %%
new_cases.columns=['ds','y']

# %%
m=Prophet(interval_width=0.95)
m.fit(new_cases)
future_new_cases=m.make_future_dataframe(periods=4)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 23.

# %%
forecast_new_cases=m.predict(future_new_cases)
forecast_new_cases[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(4)
# Out:
#            ds         yhat  yhat_lower   yhat_upper
# 30 2020-12-21   334.722475   72.931347   605.539811
# 31 2020-12-22   968.739799  669.426320  1219.960941
# 32 2020-12-23  1055.947568  773.039923  1331.573568
# 33 2020-12-24   902.658910  640.971287  1181.239917

# %%
forecast_new_cases_plot=m.plot(forecast_new_cases)

# %%
forecast_new_cases_plot=m.plot_components(forecast_new_cases)
