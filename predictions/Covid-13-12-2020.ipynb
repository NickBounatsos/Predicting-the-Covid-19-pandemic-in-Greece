# %% [markdown]
# # Covid-19 Overview in Greece

# %% [markdown]
# ## Table of contents
# * [Introduction](#introduction)
# * [Data](#data)
# * [New cases graph](#new_cases_graph)
# * [New deaths graph](#new_deaths_graph)
# * [Total cases graph](#total_cases_graph)
# * [Total deaths graph](#total_deaths_graph)
# * [Prediction of total cases](#prediction_total_cases)
# * [Prediction of total deaths](#prediction_total_deaths)
# * [Prediction of new deaths](#prediction_new_deaths)
# * [Prediction of new cases](#prediction_new_cases)

# %% [markdown]
# # Introduction <a name="introduction"></a>

# %% [markdown]
# ## Data <a name="data"></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from matplotlib.ticker import StrMethodFormatter
import seaborn as sns
import scipy
import plotly
import folium
from folium import plugins
import statsmodels.formula.api as smf
import statsmodels.api as sm
from sklearn import model_selection, preprocessing, feature_selection, ensemble, linear_model, metrics, decomposition
from lime import lime_tabular
import plotly.express as px
import plotly.graph_objects as go
import os

# %%
# !wget -nv https://covid19.who.int/WHO-COVID-19-global-data.csv
print('File downloaded!')
file_name=('WHO-COVID-19-global-data.csv')
df_raw=pd.read_csv(file_name)
print('File copied to DataFrame!')
os.remove("WHO-COVID-19-global-data.csv")
print("File Removed!")
# Out:
# File downloaded!
# File copied to DataFrame!
# File Removed!
# 2020-12-14 23:43:49 URL:https://covid19.who.int/WHO-COVID-19-global-data.csv [3481426/3481426] -> "WHO-COVID-19-global-data.csv" [1]

# %%
df_raw.head()
# Out:
#   Date_reported Country_code      Country WHO_region  New_cases  \
# 0    2020-01-03           AF  Afghanistan       EMRO          0
# 1    2020-01-04           AF  Afghanistan       EMRO          0
# 2    2020-01-05           AF  Afghanistan       EMRO          0
# 3    2020-01-06           AF  Afghanistan       EMRO          0
# 4    2020-01-07           AF  Afghanistan       EMRO          0
#
#    Cumulative_cases  New_deaths  Cumulative_deaths
# 0                 0           0                  0
# 1                 0           0                  0
# 2                 0           0                  0
# 3                 0           0                  0
# 4                 0           0                  0

# %% [markdown]
# #### Removing data from all the countries except Greece

# %%
df_raw=df_raw[df_raw['Country'].str.contains('Greece')]
df_raw.head()
# Out:
#       Date_reported Country_code Country WHO_region  New_cases  \
# 28107    2020-01-03           GR  Greece       EURO          0
# 28108    2020-01-04           GR  Greece       EURO          0
# 28109    2020-01-05           GR  Greece       EURO          0
# 28110    2020-01-06           GR  Greece       EURO          0
# 28111    2020-01-07           GR  Greece       EURO          0
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 28107                 0           0                  0
# 28108                 0           0                  0
# 28109                 0           0                  0
# 28110                 0           0                  0
# 28111                 0           0                  0

# %% [markdown]
# #### Removing unnecessary data columns

# %%
df_raw=df_raw.drop(columns=["Country_code", "WHO_region", "Country"])
df_raw.head()
# Out:
#       Date_reported  New_cases  Cumulative_cases  New_deaths  \
# 28107    2020-01-03          0                 0           0
# 28108    2020-01-04          0                 0           0
# 28109    2020-01-05          0                 0           0
# 28110    2020-01-06          0                 0           0
# 28111    2020-01-07          0                 0           0
#
#        Cumulative_deaths
# 28107                  0
# 28108                  0
# 28109                  0
# 28110                  0
# 28111                  0

# %% [markdown]
# #### Renaming columns

# %%
df_raw=df_raw.rename(columns={"Cumulative_cases": "Total_cases", "Cumulative_deaths": "Total_deaths"})
df_raw.head()
# Out:
#       Date_reported  New_cases  Total_cases  New_deaths  Total_deaths
# 28107    2020-01-03          0            0           0             0
# 28108    2020-01-04          0            0           0             0
# 28109    2020-01-05          0            0           0             0
# 28110    2020-01-06          0            0           0             0
# 28111    2020-01-07          0            0           0             0

# %% [markdown]
# #### Sorting the dataframe by Date

# %%
df_raw=df_raw.sort_values(by='Date_reported', ascending=False)
df_raw.head()
# Out:
#       Date_reported  New_cases  Total_cases  New_deaths  Total_deaths
# 28453    2020-12-14        692       124534          85          3625
# 28452    2020-12-13       1194       123842          68          3540
# 28451    2020-12-12       1395       122648         102          3472
# 28450    2020-12-11       1533       121253          81          3370
# 28449    2020-12-10       1675       119720          95          3289

# %% [markdown]
# #### Converting 'Date_reported' to datetime

# %%
df_raw.Date_reported = pd.to_datetime(df_raw.Date_reported).dt.date

# %%
df_raw.head(10)
# Out:
#       Date_reported  New_cases  Total_cases  New_deaths  Total_deaths
# 28453    2020-12-14        692       124534          85          3625
# 28452    2020-12-13       1194       123842          68          3540
# 28451    2020-12-12       1395       122648         102          3472
# 28450    2020-12-11       1533       121253          81          3370
# 28449    2020-12-10       1675       119720          95          3289
# 28448    2020-12-09       1324       118045         102          3194
# 28447    2020-12-08       1250       116721          89          3092
# 28446    2020-12-07        903       115471         101          3003
# 28445    2020-12-06       1383       114568          98          2902
# 28444    2020-12-05       1648       113185          98          2804

# %% [markdown]
# #### Correcting the deviation of the day

# %%
df_copy = df_raw.copy()
df_copy['Date_reported']=df_copy['Date_reported'].shift(-1)
df_copy.head()
# Out:
#       Date_reported  New_cases  Total_cases  New_deaths  Total_deaths
# 28453    2020-12-13        692       124534          85          3625
# 28452    2020-12-12       1194       123842          68          3540
# 28451    2020-12-11       1395       122648         102          3472
# 28450    2020-12-10       1533       121253          81          3370
# 28449    2020-12-09       1675       119720          95          3289

# %%
df_copy = df_copy.iloc[:-310]

# %%
df_copy=df_copy.sort_values(by='Total_cases', ascending=True)

# %%
df_copy.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
# #T_73e9aed9_3e55_11eb_8eef_309c2382d253row0_col1,#T_73e9aed9_3e55_11eb_8eef_309c2382d253row13_col1,#T_73e9aed9_3e55_11eb_8eef_309c2382d253row22_col2{
#             background-color:  #d72322;
#             color:  #f1f1f1;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row0_col2,#T_73e9aed9_3e55_11eb_8eef_309c2382d253row0_col3,#T_73e9aed9_3e55_11eb_8eef_309c2382d253row0_col4,#T_73e9aed9_3e55_11eb_8eef_309c2382d253row36_col1{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row1_col1,#T_73e9aed9_3e55_11eb_8eef_309c2382d253row26_col1{
#             background-color:  #fb7858;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row1_col2,#T_73e9aed9_3e55_11eb_8eef_309c2382d253row2_col4{
#             background-color:  #fff1ea;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row1_col3{
#             background-color:  #fff4ee;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row1_col4{
#             background-color:  #fff3ed;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row2_col1{
#             background-color:  #fcaa8d;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row2_col2{
#             background-color:  #ffede5;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row2_col3,#T_73e9aed9_3e55_11eb_8eef_309c2382d253row3_col3,#T_73e9aed9_3e55_11eb_8eef_309c2382d253row29_col1{
#             background-color:  #fee8dd;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row3_col1{
#             background-color:  #ea362a;
#             color:  #f1f1f1;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row3_col2{
#             background-color:  #fee7dc;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row3_col4{
#             background-color:  #ffeee7;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row4_col1,#T_73e9aed9_3e55_11eb_8eef_309c2382d253row29_col4,#T_73e9aed9_3e55_11eb_8eef_309c2382d253row31_col3,#T_73e9aed9_3e55_11eb_8eef_309c2382d253row34_col3{
#             background-color:  #c1161b;
#             color:  #f1f1f1;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row4_col2,#T_73e9aed9_3e55_11eb_8eef_309c2382d253row8_col4{
#             background-color:  #fee1d3;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row4_col3{
#             background-color:  #fee4d8;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row4_col4{
#             background-color:  #ffece3;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row5_col1,#T_73e9aed9_3e55_11eb_8eef_309c2382d253row21_col3,#T_73e9aed9_3e55_11eb_8eef_309c2382d253row36_col2,#T_73e9aed9_3e55_11eb_8eef_309c2382d253row36_col4{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row5_col2{
#             background-color:  #fdd3c1;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row5_col3,#T_73e9aed9_3e55_11eb_8eef_309c2382d253row11_col4{
#             background-color:  #fdcebb;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row5_col4{
#             background-color:  #fee9df;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row6_col1{
#             background-color:  #9c0d14;
#             color:  #f1f1f1;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row6_col2,#T_73e9aed9_3e55_11eb_8eef_309c2382d253row30_col1{
#             background-color:  #fdc6b0;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row6_col3,#T_73e9aed9_3e55_11eb_8eef_309c2382d253row7_col3{
#             background-color:  #ffeee6;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row6_col4{
#             background-color:  #fee7db;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row7_col1{
#             background-color:  #b61319;
#             color:  #f1f1f1;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row7_col2{
#             background-color:  #fcbba1;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row7_col4{
#             background-color:  #fee5d8;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row8_col1{
#             background-color:  #fc9070;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row8_col2{
#             background-color:  #fcb296;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row8_col3{
#             background-color:  #fc8262;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row9_col1{
#             background-color:  #f44f39;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row9_col2{
#             background-color:  #fca78b;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row9_col3,#T_73e9aed9_3e55_11eb_8eef_309c2382d253row12_col3{
#             background-color:  #fcaf93;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row9_col4{
#             background-color:  #fedaca;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row10_col1{
#             background-color:  #e53228;
#             color:  #f1f1f1;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row10_col2{
#             background-color:  #fc9c7d;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row10_col3,#T_73e9aed9_3e55_11eb_8eef_309c2382d253row16_col4{
#             background-color:  #fca082;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row10_col4{
#             background-color:  #fdd4c2;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row11_col1{
#             background-color:  #7a0510;
#             color:  #f1f1f1;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row11_col2{
#             background-color:  #fc8e6e;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row11_col3{
#             background-color:  #fcab8f;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row12_col1{
#             background-color:  #77040f;
#             color:  #f1f1f1;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row12_col2,#T_73e9aed9_3e55_11eb_8eef_309c2382d253row13_col3,#T_73e9aed9_3e55_11eb_8eef_309c2382d253row19_col4{
#             background-color:  #fc7f5f;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row12_col4{
#             background-color:  #fdc7b2;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row13_col2{
#             background-color:  #fb7252;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row13_col4{
#             background-color:  #fcc1a8;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row14_col1,#T_73e9aed9_3e55_11eb_8eef_309c2382d253row24_col4{
#             background-color:  #f03f2e;
#             color:  #f1f1f1;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row14_col2,#T_73e9aed9_3e55_11eb_8eef_309c2382d253row19_col1{
#             background-color:  #fa6849;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row14_col3,#T_73e9aed9_3e55_11eb_8eef_309c2382d253row31_col4{
#             background-color:  #ac1117;
#             color:  #f1f1f1;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row14_col4{
#             background-color:  #fcb499;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row15_col1,#T_73e9aed9_3e55_11eb_8eef_309c2382d253row15_col4{
#             background-color:  #fca98c;
#             color:  #000000;
#         }#T_73e9aed9_3e55_11eb_8eef_309c2382d253row15_col2{
#             background-color:  #f8

# %% [markdown]
# # New cases graph<a name="new_cases_graph"></a>

# %%
plt.figure(figsize=(30,12))
plt.title('New cases in Greece (7 November 2020 - today)', fontsize=30)
plt.ylabel('New Cases', fontsize=30)
plt.xlabel('Date', fontsize=30)
plt.xticks(rotation=90)
plt.tick_params(axis='x', labelsize=17)
plt.tick_params(axis='y', labelsize=25)
plt.plot(df_copy['Date_reported'], df_copy['New_cases'])

# %% [markdown]
# # New deaths graph<a name="new_deaths_graph"></a>

# %%
plt.figure(figsize=(30,12))
plt.title('New deaths in Greece (7 November 2020 - today)',fontsize=30)
plt.ylabel('New Deaths',fontsize=30)
plt.xlabel('Date',fontsize=30)
plt.xticks(rotation=90)
plt.tick_params(axis='y', labelsize=25)
plt.tick_params(axis='x', labelsize=18)
plt.plot(df_copy['Date_reported'], df_copy['New_deaths'])

# %% [markdown]
# # Total cases graph<a name="total_cases_graph"></a>

# %%
plt.figure(figsize=(30,12))
plt.title('Total cases in Greece (7 November 2020 - today)',fontsize=30)
plt.ylabel('Total Cases',fontsize=30)
plt.xlabel('Date',fontsize=30)
plt.xticks(rotation=90)
plt.tick_params(axis='x', labelsize=18)
plt.tick_params(axis='y', labelsize=25)
plt.plot(df_copy['Date_reported'], df_copy['Total_cases'])

# %% [markdown]
# # Total deaths graph<a name="total_deaths_graph"></a>

# %%
plt.figure(figsize=(30,12))
plt.title('Total deaths in Greece (7 November 2020 - today)',fontsize=30)
plt.ylabel('Total Deaths',fontsize=30)
plt.xlabel('Date',fontsize=30)
plt.xticks(rotation=90)
plt.tick_params(axis='x', labelsize=18)
plt.tick_params(axis='y', labelsize=25)
plt.plot(df_copy['Date_reported'], df_copy['Total_deaths'])

# %% [markdown]
# ## Using Prophet to predict covid-19 behavior to 1 week from today

# %%
from fbprophet import Prophet

# %%
new_cases=df_copy.groupby('Date_reported').sum()['New_cases'].reset_index()
new_deaths=df_copy.groupby('Date_reported').sum()['New_deaths'].reset_index()
total_cases=df_copy.groupby('Date_reported').sum()['Total_cases'].reset_index()
total_deaths=df_copy.groupby('Date_reported').sum()['Total_deaths'].reset_index()

# %% [markdown]
# ## Prediction of Total Cases<a name="prediction_total_cases"></a>

# %%
total_cases.tail()
# Out:
#    Date_reported  Total_cases
# 32    2020-12-09       119720
# 33    2020-12-10       121253
# 34    2020-12-11       122648
# 35    2020-12-12       123842
# 36    2020-12-13       124534

# %%
total_cases.columns=['ds','y']

# %%
m=Prophet(interval_width=0.95)
m.fit(total_cases)
future_total_cases=m.make_future_dataframe(periods=4)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast_total_cases=m.predict(future_total_cases)
forecast_total_cases[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(4)
# Out:
#            ds           yhat     yhat_lower     yhat_upper
# 37 2020-12-14  125555.135308  125282.436601  125814.541058
# 38 2020-12-15  127095.710207  126519.412446  127707.738437
# 39 2020-12-16  128786.363057  127750.428929  129922.285445
# 40 2020-12-17  130380.968515  128717.961246  132064.815650

# %%
forecast_total_cases_plot=m.plot(forecast_total_cases)

# %%
forecast_total_cases_plot=m.plot_components(forecast_total_cases)

# %% [markdown]
# ## Prediction of total deaths<a name="prediction_total_deaths"></a>

# %%
total_deaths.tail()
# Out:
#    Date_reported  Total_deaths
# 32    2020-12-09          3289
# 33    2020-12-10          3370
# 34    2020-12-11          3472
# 35    2020-12-12          3540
# 36    2020-12-13          3625

# %%
total_deaths.columns=['ds','y']

# %%
m=Prophet(interval_width=0.95)
m.fit(total_deaths)
future_total_deaths=m.make_future_dataframe(periods=4)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast_total_deaths=m.predict(future_total_deaths)
forecast_total_deaths[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(4)
# Out:
#            ds         yhat   yhat_lower   yhat_upper
# 37 2020-12-14  3731.217326  3717.780640  3744.678532
# 38 2020-12-15  3828.945401  3810.399783  3846.084114
# 39 2020-12-16  3916.969822  3891.088376  3940.366148
# 40 2020-12-17  4006.416518  3966.472507  4039.833278

# %%
forecast_total_deaths_plot=m.plot(forecast_total_deaths)

# %%
forecast_total_deaths_plot=m.plot_components(forecast_total_deaths)

# %% [markdown]
# ## Prediction of new deaths <a name="prediction_new_deaths"></a>

# %%
new_deaths.tail()
# Out:
#    Date_reported  New_deaths
# 32    2020-12-09          95
# 33    2020-12-10          81
# 34    2020-12-11         102
# 35    2020-12-12          68
# 36    2020-12-13          85

# %%
new_deaths.columns=['ds','y']

# %%
m=Prophet(interval_width=0.95)
m.fit(new_deaths)
future_new_deaths=m.make_future_dataframe(periods=4)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast_new_deaths=m.predict(future_new_deaths)
forecast_new_deaths[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(4)
# Out:
#            ds        yhat  yhat_lower  yhat_upper
# 37 2020-12-14  107.934758   75.829024  139.511208
# 38 2020-12-15  119.935392   86.365609  151.009234
# 39 2020-12-16  111.127652   78.970876  143.013433
# 40 2020-12-17  114.124746   84.471103  147.156233

# %%
forecast_new_deaths_plot=m.plot(forecast_new_deaths)

# %%
forecast_new_deaths_plot=m.plot_components(forecast_new_deaths)

# %% [markdown]
# ## Prediction of new cases<a name="prediction_new_cases"></a>

# %%
new_cases.tail()
# Out:
#    Date_reported  New_cases
# 32    2020-12-09       1675
# 33    2020-12-10       1533
# 34    2020-12-11       1395
# 35    2020-12-12       1194
# 36    2020-12-13        692

# %%
new_cases.columns=['ds','y']

# %%
m=Prophet(interval_width=0.95)
m.fit(new_cases)
future_new_cases=m.make_future_dataframe(periods=4)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast_new_cases=m.predict(future_new_cases)
forecast_new_cases[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(4)
# Out:
#            ds         yhat  yhat_lower   yhat_upper
# 37 2020-12-14   541.105062   33.957447  1067.442071
# 38 2020-12-15  1159.238603  668.244194  1657.694760
# 39 2020-12-16  1461.600817  961.088204  1991.204855
# 40 2020-12-17  1462.594032  963.680706  1944.504091

# %%
forecast_new_cases_plot=m.plot(forecast_new_cases)

# %%
forecast_new_cases_plot=m.plot_components(forecast_new_cases)
