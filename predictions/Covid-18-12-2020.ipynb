# %% [markdown]
# # Covid-19 Overview in Greece

# %% [markdown]
# ## Table of contents
# * [Introduction](#introduction)
# * [Data](#data)
# * [New cases graph](#new_cases_graph)
# * [New deaths graph](#new_deaths_graph)
# * [Total cases graph](#total_cases_graph)
# * [Total deaths graph](#total_deaths_graph)
# * [Prediction of total cases](#prediction_total_cases)
# * [Prediction of total deaths](#prediction_total_deaths)
# * [Prediction of new deaths](#prediction_new_deaths)
# * [Prediction of new cases](#prediction_new_cases)

# %% [markdown]
# # Introduction <a name="introduction"></a>

# %% [markdown]
# ## Data <a name="data"></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from matplotlib.ticker import StrMethodFormatter
import seaborn as sns
import scipy
import plotly
import folium
from folium import plugins
import statsmodels.formula.api as smf
import statsmodels.api as sm
from sklearn import model_selection, preprocessing, feature_selection, ensemble, linear_model, metrics, decomposition
from lime import lime_tabular
import plotly.express as px
import plotly.graph_objects as go
import os

# %%
#!wget -nv https://covid19.who.int/WHO-COVID-19-global-data.csv
#print('File downloaded!')
file_name=('cov.csv')
df_raw=pd.read_csv(file_name)
print('File copied to DataFrame!')
#os.remove("WHO-COVID-19-global-data.csv")
#print("File Removed!")
# Out:
# File copied to DataFrame!

# %%
df_raw.head()
# Out:
#   Date_reported Country_code      Country WHO_region  New_cases  \
# 0    2020-01-03           AF  Afghanistan       EMRO          0
# 1    2020-01-04           AF  Afghanistan       EMRO          0
# 2    2020-01-05           AF  Afghanistan       EMRO          0
# 3    2020-01-06           AF  Afghanistan       EMRO          0
# 4    2020-01-07           AF  Afghanistan       EMRO          0
#
#    Cumulative_cases  New_deaths  Cumulative_deaths
# 0                 0           0                  0
# 1                 0           0                  0
# 2                 0           0                  0
# 3                 0           0                  0
# 4                 0           0                  0

# %% [markdown]
# #### Removing data from all the countries except Greece

# %%
df_raw=df_raw[df_raw['Country'].str.contains('Greece')]
df_raw.head()
# Out:
#       Date_reported Country_code Country WHO_region  New_cases  \
# 28269    2020-01-03           GR  Greece       EURO          0
# 28270    2020-01-04           GR  Greece       EURO          0
# 28271    2020-01-05           GR  Greece       EURO          0
# 28272    2020-01-06           GR  Greece       EURO          0
# 28273    2020-01-07           GR  Greece       EURO          0
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 28269                 0           0                  0
# 28270                 0           0                  0
# 28271                 0           0                  0
# 28272                 0           0                  0
# 28273                 0           0                  0

# %% [markdown]
# #### Removing unnecessary data columns

# %%
df_raw=df_raw.drop(columns=["Country_code", "WHO_region", "Country"])
df_raw.head()
# Out:
#       Date_reported  New_cases  Cumulative_cases  New_deaths  \
# 28269    2020-01-03          0                 0           0
# 28270    2020-01-04          0                 0           0
# 28271    2020-01-05          0                 0           0
# 28272    2020-01-06          0                 0           0
# 28273    2020-01-07          0                 0           0
#
#        Cumulative_deaths
# 28269                  0
# 28270                  0
# 28271                  0
# 28272                  0
# 28273                  0

# %% [markdown]
# #### Renaming columns

# %%
df_raw=df_raw.rename(columns={"Cumulative_cases": "Total_cases", "Cumulative_deaths": "Total_deaths"})
df_raw.head()
# Out:
#       Date_reported  New_cases  Total_cases  New_deaths  Total_deaths
# 28269    2020-01-03          0            0           0             0
# 28270    2020-01-04          0            0           0             0
# 28271    2020-01-05          0            0           0             0
# 28272    2020-01-06          0            0           0             0
# 28273    2020-01-07          0            0           0             0

# %% [markdown]
# #### Sorting the dataframe by Date

# %%
df_raw=df_raw.sort_values(by='Date_reported', ascending=False)
df_raw.head()
# Out:
#       Date_reported  New_cases  Total_cases  New_deaths  Total_deaths
# 28620    2020-12-19        916       129633          96          4026
# 28619    2020-12-18       1155       128717          78          3948
# 28618    2020-12-17       1190       127562          85          3870
# 28617    2020-12-16       1199       126372          98          3785
# 28616    2020-12-15        639       125173          62          3687

# %% [markdown]
# #### Converting 'Date_reported' to datetime

# %%
df_raw.Date_reported = pd.to_datetime(df_raw.Date_reported).dt.date

# %%
df_raw.head(10)
# Out:
#       Date_reported  New_cases  Total_cases  New_deaths  Total_deaths
# 28620    2020-12-19        916       129633          96          4026
# 28619    2020-12-18       1155       128717          78          3948
# 28618    2020-12-17       1190       127562          85          3870
# 28617    2020-12-16       1199       126372          98          3785
# 28616    2020-12-15        639       125173          62          3687
# 28615    2020-12-14        692       124534          85          3625
# 28614    2020-12-13       1194       123842          68          3540
# 28613    2020-12-12       1395       122648         102          3472
# 28612    2020-12-11       1533       121253          81          3370
# 28611    2020-12-10       1675       119720          95          3289

# %% [markdown]
# #### Correcting the deviation of the day

# %%
df_copy = df_raw.copy()
df_copy['Date_reported']=df_copy['Date_reported'].shift(-1)
df_copy.head()
# Out:
#       Date_reported  New_cases  Total_cases  New_deaths  Total_deaths
# 28620    2020-12-18        916       129633          96          4026
# 28619    2020-12-17       1155       128717          78          3948
# 28618    2020-12-16       1190       127562          85          3870
# 28617    2020-12-15       1199       126372          98          3785
# 28616    2020-12-14        639       125173          62          3687

# %%
df_copy = df_copy.iloc[:-310]

# %%
df_copy=df_copy.sort_values(by='Total_cases', ascending=True)

# %%
df_copy.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
# #T_9bac4baf_414a_11eb_912e_309c2382d253row0_col1,#T_9bac4baf_414a_11eb_912e_309c2382d253row30_col4{
#             background-color:  #d42121;
#             color:  #f1f1f1;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row0_col2,#T_9bac4baf_414a_11eb_912e_309c2382d253row0_col3,#T_9bac4baf_414a_11eb_912e_309c2382d253row0_col4,#T_9bac4baf_414a_11eb_912e_309c2382d253row37_col1{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row1_col1{
#             background-color:  #fb7555;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row1_col2{
#             background-color:  #fff1ea;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row1_col3,#T_9bac4baf_414a_11eb_912e_309c2382d253row1_col4{
#             background-color:  #fff4ee;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row2_col1{
#             background-color:  #fca588;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row2_col2,#T_9bac4baf_414a_11eb_912e_309c2382d253row6_col3,#T_9bac4baf_414a_11eb_912e_309c2382d253row7_col3{
#             background-color:  #ffeee6;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row2_col3,#T_9bac4baf_414a_11eb_912e_309c2382d253row3_col3{
#             background-color:  #fee8dd;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row2_col4,#T_9bac4baf_414a_11eb_912e_309c2382d253row36_col1{
#             background-color:  #fff2eb;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row3_col1{
#             background-color:  #e83429;
#             color:  #f1f1f1;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row3_col2,#T_9bac4baf_414a_11eb_912e_309c2382d253row6_col4{
#             background-color:  #fee8de;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row3_col4{
#             background-color:  #ffefe8;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row4_col1{
#             background-color:  #bf151b;
#             color:  #f1f1f1;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row4_col2{
#             background-color:  #fee2d5;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row4_col3,#T_9bac4baf_414a_11eb_912e_309c2382d253row41_col1{
#             background-color:  #fee4d8;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row4_col4{
#             background-color:  #ffede5;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row5_col1,#T_9bac4baf_414a_11eb_912e_309c2382d253row21_col3,#T_9bac4baf_414a_11eb_912e_309c2382d253row41_col2,#T_9bac4baf_414a_11eb_912e_309c2382d253row41_col4{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row5_col2{
#             background-color:  #fdd7c6;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row5_col3{
#             background-color:  #fdcebb;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row5_col4{
#             background-color:  #feeae1;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row6_col1,#T_9bac4baf_414a_11eb_912e_309c2382d253row37_col4{
#             background-color:  #9a0c14;
#             color:  #f1f1f1;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row6_col2{
#             background-color:  #fdcbb6;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row7_col1{
#             background-color:  #b51318;
#             color:  #f1f1f1;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row7_col2,#T_9bac4baf_414a_11eb_912e_309c2382d253row14_col4{
#             background-color:  #fcbfa7;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row7_col4{
#             background-color:  #fee7db;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row8_col1,#T_9bac4baf_414a_11eb_912e_309c2382d253row35_col3{
#             background-color:  #fc8d6d;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row8_col2{
#             background-color:  #fcb89e;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row8_col3{
#             background-color:  #fc8262;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row8_col4{
#             background-color:  #fee3d7;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row9_col1,#T_9bac4baf_414a_11eb_912e_309c2382d253row24_col1{
#             background-color:  #f34a36;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row9_col2,#T_9bac4baf_414a_11eb_912e_309c2382d253row9_col3,#T_9bac4baf_414a_11eb_912e_309c2382d253row12_col3{
#             background-color:  #fcaf93;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row9_col4{
#             background-color:  #fee0d2;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row10_col1{
#             background-color:  #e32f27;
#             color:  #f1f1f1;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row10_col2,#T_9bac4baf_414a_11eb_912e_309c2382d253row15_col1,#T_9bac4baf_414a_11eb_912e_309c2382d253row37_col3{
#             background-color:  #fca486;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row10_col3,#T_9bac4baf_414a_11eb_912e_309c2382d253row33_col1{
#             background-color:  #fca082;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row10_col4{
#             background-color:  #fedaca;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row11_col1{
#             background-color:  #7a0510;
#             color:  #f1f1f1;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row11_col2{
#             background-color:  #fc9576;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row11_col3{
#             background-color:  #fcab8f;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row11_col4{
#             background-color:  #fdd4c2;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row12_col1{
#             background-color:  #77040f;
#             color:  #f1f1f1;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row12_col2{
#             background-color:  #fc8767;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row12_col4{
#             background-color:  #fdd0bc;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row13_col1,#T_9bac4baf_414a_11eb_912e_309c2382d253row41_col3{
#             background-color:  #d52221;
#             color:  #f1f1f1;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row13_col2{
#             background-color:  #fb7d5d;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row13_col3{
#             background-color:  #fc7f5f;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row13_col4,#T_9bac4baf_414a_11eb_912e_309c2382d253row22_col1,#T_9bac4baf_414a_11eb_912e_309c2382d253row39_col1{
#             background-color:  #fdc9b3;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row14_col1,#T_9bac4baf_414a_11eb_912e_309c2382d253row20_col2{
#             background-color:  #ef3c2c;
#             color:  #f1f1f1;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row14_col2{
#             background-color:  #fb7353;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row14_col3{
#             background-color:  #ac1117;
#             color:  #f1f1f1;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row15_col2{
#             background-color:  #fb6d4d;
#             color:  #000000;
#         }#T_9bac4baf_414a_11eb_912e_309c2382d253row15_col3{
#             background-color:  #bd

# %% [markdown]
# # New cases graph<a name="new_cases_graph"></a>

# %%
plt.figure(figsize=(30,12))
plt.title('New cases in Greece (7 November 2020 - today)', fontsize=30)
plt.ylabel('New Cases', fontsize=30)
plt.xlabel('Date', fontsize=30)
plt.xticks(rotation=90)
plt.tick_params(axis='x', labelsize=17)
plt.tick_params(axis='y', labelsize=25)
plt.plot(df_copy['Date_reported'], df_copy['New_cases'])

# %% [markdown]
# # New deaths graph<a name="new_deaths_graph"></a>

# %%
plt.figure(figsize=(30,12))
plt.title('New deaths in Greece (7 November 2020 - today)',fontsize=30)
plt.ylabel('New Deaths',fontsize=30)
plt.xlabel('Date',fontsize=30)
plt.xticks(rotation=90)
plt.tick_params(axis='y', labelsize=25)
plt.tick_params(axis='x', labelsize=18)
plt.plot(df_copy['Date_reported'], df_copy['New_deaths'])

# %% [markdown]
# # Total cases graph<a name="total_cases_graph"></a>

# %%
plt.figure(figsize=(30,12))
plt.title('Total cases in Greece (7 November 2020 - today)',fontsize=30)
plt.ylabel('Total Cases',fontsize=30)
plt.xlabel('Date',fontsize=30)
plt.xticks(rotation=90)
plt.tick_params(axis='x', labelsize=18)
plt.tick_params(axis='y', labelsize=25)
plt.plot(df_copy['Date_reported'], df_copy['Total_cases'])

# %% [markdown]
# # Total deaths graph<a name="total_deaths_graph"></a>

# %%
plt.figure(figsize=(30,12))
plt.title('Total deaths in Greece (7 November 2020 - today)',fontsize=30)
plt.ylabel('Total Deaths',fontsize=30)
plt.xlabel('Date',fontsize=30)
plt.xticks(rotation=90)
plt.tick_params(axis='x', labelsize=18)
plt.tick_params(axis='y', labelsize=25)
plt.plot(df_copy['Date_reported'], df_copy['Total_deaths'])

# %% [markdown]
# ## Using Prophet to predict covid-19 behavior to 1 week from today

# %%
from fbprophet import Prophet

# %%
new_cases=df_copy.groupby('Date_reported').sum()['New_cases'].reset_index()
new_deaths=df_copy.groupby('Date_reported').sum()['New_deaths'].reset_index()
total_cases=df_copy.groupby('Date_reported').sum()['Total_cases'].reset_index()
total_deaths=df_copy.groupby('Date_reported').sum()['Total_deaths'].reset_index()

# %% [markdown]
# ## Prediction of Total Cases<a name="prediction_total_cases"></a>

# %%
total_cases.tail()
# Out:
#    Date_reported  Total_cases
# 37    2020-12-14       125173
# 38    2020-12-15       126372
# 39    2020-12-16       127562
# 40    2020-12-17       128717
# 41    2020-12-18       129633

# %%
total_cases.columns=['ds','y']

# %%
m=Prophet(interval_width=0.95)
m.fit(total_cases)
future_total_cases=m.make_future_dataframe(periods=4)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast_total_cases=m.predict(future_total_cases)
forecast_total_cases[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(4)
# Out:
#            ds           yhat     yhat_lower     yhat_upper
# 42 2020-12-19  131321.861846  131026.646633  131621.769403
# 43 2020-12-20  131906.841908  131337.443318  132579.081389
# 44 2020-12-21  132491.341788  131405.433863  133704.631780
# 45 2020-12-22  133658.122014  132122.110938  135450.617225

# %%
forecast_total_cases_plot=m.plot(forecast_total_cases)

# %%
forecast_total_cases_plot=m.plot_components(forecast_total_cases)

# %% [markdown]
# ## Prediction of total deaths<a name="prediction_total_deaths"></a>

# %%
total_deaths.tail()
# Out:
#    Date_reported  Total_deaths
# 37    2020-12-14          3687
# 38    2020-12-15          3785
# 39    2020-12-16          3870
# 40    2020-12-17          3948
# 41    2020-12-18          4026

# %%
total_deaths.columns=['ds','y']

# %%
m=Prophet(interval_width=0.95)
m.fit(total_deaths)
future_total_deaths=m.make_future_dataframe(periods=4)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast_total_deaths=m.predict(future_total_deaths)
forecast_total_deaths[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(4)
# Out:
#            ds         yhat   yhat_lower   yhat_upper
# 42 2020-12-19  4113.453094  4102.965955  4124.230376
# 43 2020-12-20  4198.378416  4182.582541  4214.777677
# 44 2020-12-21  4270.513574  4248.219714  4295.117614
# 45 2020-12-22  4358.650068  4322.100795  4394.972317

# %%
forecast_total_deaths_plot=m.plot(forecast_total_deaths)

# %%
forecast_total_deaths_plot=m.plot_components(forecast_total_deaths)

# %% [markdown]
# ## Prediction of new deaths <a name="prediction_new_deaths"></a>

# %%
new_deaths.tail()
# Out:
#    Date_reported  New_deaths
# 37    2020-12-14          62
# 38    2020-12-15          98
# 39    2020-12-16          85
# 40    2020-12-17          78
# 41    2020-12-18          96

# %%
new_deaths.columns=['ds','y']

# %%
m=Prophet(interval_width=0.95)
m.fit(new_deaths)
future_new_deaths=m.make_future_dataframe(periods=4)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast_new_deaths=m.predict(future_new_deaths)
forecast_new_deaths[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(4)
# Out:
#            ds        yhat  yhat_lower  yhat_upper
# 42 2020-12-19  109.253198   75.707897  144.567912
# 43 2020-12-20  113.575567   80.869219  147.459671
# 44 2020-12-21  101.424326   66.589310  141.491045
# 45 2020-12-22  117.394618   82.968455  150.297733

# %%
forecast_new_deaths_plot=m.plot(forecast_new_deaths)

# %%
forecast_new_deaths_plot=m.plot_components(forecast_new_deaths)

# %% [markdown]
# ## Prediction of new cases<a name="prediction_new_cases"></a>

# %%
new_cases.tail()
# Out:
#    Date_reported  New_cases
# 37    2020-12-14        639
# 38    2020-12-15       1199
# 39    2020-12-16       1190
# 40    2020-12-17       1155
# 41    2020-12-18        916

# %%
new_cases.columns=['ds','y']

# %%
m=Prophet(interval_width=0.95)
m.fit(new_cases)
future_new_cases=m.make_future_dataframe(periods=4)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast_new_cases=m.predict(future_new_cases)
forecast_new_cases[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(4)
# Out:
#            ds        yhat  yhat_lower   yhat_upper
# 42 2020-12-19  863.731608  318.693111  1362.997844
# 43 2020-12-20  171.263222 -327.845085   672.578787
# 44 2020-12-21  194.124053 -296.951197   707.865220
# 45 2020-12-22  802.922733  288.875088  1295.157061

# %%
forecast_new_cases_plot=m.plot(forecast_new_cases)

# %%
forecast_new_cases_plot=m.plot_components(forecast_new_cases)
