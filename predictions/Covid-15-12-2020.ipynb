# %% [markdown]
# # Covid-19 Overview in Greece

# %% [markdown]
# ## Table of contents
# * [Introduction](#introduction)
# * [Data](#data)
# * [New cases graph](#new_cases_graph)
# * [New deaths graph](#new_deaths_graph)
# * [Total cases graph](#total_cases_graph)
# * [Total deaths graph](#total_deaths_graph)
# * [Prediction of total cases](#prediction_total_cases)
# * [Prediction of total deaths](#prediction_total_deaths)
# * [Prediction of new deaths](#prediction_new_deaths)
# * [Prediction of new cases](#prediction_new_cases)

# %% [markdown]
# # Introduction <a name="introduction"></a>

# %% [markdown]
# ## Data <a name="data"></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from matplotlib.ticker import StrMethodFormatter
import seaborn as sns
import scipy
import plotly
import folium
from folium import plugins
import statsmodels.formula.api as smf
import statsmodels.api as sm
from sklearn import model_selection, preprocessing, feature_selection, ensemble, linear_model, metrics, decomposition
from lime import lime_tabular
import plotly.express as px
import plotly.graph_objects as go
import os

# %%
# !wget -nv https://covid19.who.int/WHO-COVID-19-global-data.csv
print('File downloaded!')
file_name=('WHO-COVID-19-global-data.csv')
df_raw=pd.read_csv(file_name)
print('File copied to DataFrame!')
os.remove("WHO-COVID-19-global-data.csv")
print("File Removed!")
# Out:
# File downloaded!
# File copied to DataFrame!
# File Removed!
# 2020-12-16 23:39:45 URL:https://covid19.who.int/WHO-COVID-19-global-data.csv [3502951/3502951] -> "WHO-COVID-19-global-data.csv" [1]

# %%
df_raw.head()
# Out:
#   Date_reported Country_code      Country WHO_region  New_cases  \
# 0    2020-01-03           AF  Afghanistan       EMRO          0
# 1    2020-01-04           AF  Afghanistan       EMRO          0
# 2    2020-01-05           AF  Afghanistan       EMRO          0
# 3    2020-01-06           AF  Afghanistan       EMRO          0
# 4    2020-01-07           AF  Afghanistan       EMRO          0
#
#    Cumulative_cases  New_deaths  Cumulative_deaths
# 0                 0           0                  0
# 1                 0           0                  0
# 2                 0           0                  0
# 3                 0           0                  0
# 4                 0           0                  0

# %% [markdown]
# #### Removing data from all the countries except Greece

# %%
df_raw=df_raw[df_raw['Country'].str.contains('Greece')]
df_raw.head()
# Out:
#       Date_reported Country_code Country WHO_region  New_cases  \
# 28269    2020-01-03           GR  Greece       EURO          0
# 28270    2020-01-04           GR  Greece       EURO          0
# 28271    2020-01-05           GR  Greece       EURO          0
# 28272    2020-01-06           GR  Greece       EURO          0
# 28273    2020-01-07           GR  Greece       EURO          0
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 28269                 0           0                  0
# 28270                 0           0                  0
# 28271                 0           0                  0
# 28272                 0           0                  0
# 28273                 0           0                  0

# %% [markdown]
# #### Removing unnecessary data columns

# %%
df_raw=df_raw.drop(columns=["Country_code", "WHO_region", "Country"])
df_raw.head()
# Out:
#       Date_reported  New_cases  Cumulative_cases  New_deaths  \
# 28269    2020-01-03          0                 0           0
# 28270    2020-01-04          0                 0           0
# 28271    2020-01-05          0                 0           0
# 28272    2020-01-06          0                 0           0
# 28273    2020-01-07          0                 0           0
#
#        Cumulative_deaths
# 28269                  0
# 28270                  0
# 28271                  0
# 28272                  0
# 28273                  0

# %% [markdown]
# #### Renaming columns

# %%
df_raw=df_raw.rename(columns={"Cumulative_cases": "Total_cases", "Cumulative_deaths": "Total_deaths"})
df_raw.head()
# Out:
#       Date_reported  New_cases  Total_cases  New_deaths  Total_deaths
# 28269    2020-01-03          0            0           0             0
# 28270    2020-01-04          0            0           0             0
# 28271    2020-01-05          0            0           0             0
# 28272    2020-01-06          0            0           0             0
# 28273    2020-01-07          0            0           0             0

# %% [markdown]
# #### Sorting the dataframe by Date

# %%
df_raw=df_raw.sort_values(by='Date_reported', ascending=False)
df_raw.head()
# Out:
#       Date_reported  New_cases  Total_cases  New_deaths  Total_deaths
# 28617    2020-12-16       1199       126372          98          3785
# 28616    2020-12-15        639       125173          62          3687
# 28615    2020-12-14        692       124534          85          3625
# 28614    2020-12-13       1194       123842          68          3540
# 28613    2020-12-12       1395       122648         102          3472

# %% [markdown]
# #### Converting 'Date_reported' to datetime

# %%
df_raw.Date_reported = pd.to_datetime(df_raw.Date_reported).dt.date

# %%
df_raw.head(10)
# Out:
#       Date_reported  New_cases  Total_cases  New_deaths  Total_deaths
# 28617    2020-12-16       1199       126372          98          3785
# 28616    2020-12-15        639       125173          62          3687
# 28615    2020-12-14        692       124534          85          3625
# 28614    2020-12-13       1194       123842          68          3540
# 28613    2020-12-12       1395       122648         102          3472
# 28612    2020-12-11       1533       121253          81          3370
# 28611    2020-12-10       1675       119720          95          3289
# 28610    2020-12-09       1324       118045         102          3194
# 28609    2020-12-08       1250       116721          89          3092
# 28608    2020-12-07        903       115471         101          3003

# %% [markdown]
# #### Correcting the deviation of the day

# %%
df_copy = df_raw.copy()
df_copy['Date_reported']=df_copy['Date_reported'].shift(-1)
df_copy.head()
# Out:
#       Date_reported  New_cases  Total_cases  New_deaths  Total_deaths
# 28617    2020-12-15       1199       126372          98          3785
# 28616    2020-12-14        639       125173          62          3687
# 28615    2020-12-13        692       124534          85          3625
# 28614    2020-12-12       1194       123842          68          3540
# 28613    2020-12-11       1395       122648         102          3472

# %%
df_copy = df_copy.iloc[:-310]

# %%
df_copy=df_copy.sort_values(by='Total_cases', ascending=True)

# %%
df_copy.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
# #T_3700fa51_3fe7_11eb_bf72_309c2382d253row0_col1{
#             background-color:  #d42121;
#             color:  #f1f1f1;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row0_col2,#T_3700fa51_3fe7_11eb_bf72_309c2382d253row0_col3,#T_3700fa51_3fe7_11eb_bf72_309c2382d253row0_col4,#T_3700fa51_3fe7_11eb_bf72_309c2382d253row37_col1{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row1_col1{
#             background-color:  #fb7555;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row1_col2,#T_3700fa51_3fe7_11eb_bf72_309c2382d253row2_col4{
#             background-color:  #fff1ea;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row1_col3,#T_3700fa51_3fe7_11eb_bf72_309c2382d253row1_col4{
#             background-color:  #fff4ee;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row2_col1,#T_3700fa51_3fe7_11eb_bf72_309c2382d253row16_col4{
#             background-color:  #fca588;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row2_col2{
#             background-color:  #ffede5;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row2_col3,#T_3700fa51_3fe7_11eb_bf72_309c2382d253row3_col2,#T_3700fa51_3fe7_11eb_bf72_309c2382d253row3_col3,#T_3700fa51_3fe7_11eb_bf72_309c2382d253row6_col4{
#             background-color:  #fee8dd;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row3_col1,#T_3700fa51_3fe7_11eb_bf72_309c2382d253row20_col2{
#             background-color:  #e83429;
#             color:  #f1f1f1;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row3_col4{
#             background-color:  #ffefe8;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row4_col1{
#             background-color:  #bf151b;
#             color:  #f1f1f1;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row4_col2,#T_3700fa51_3fe7_11eb_bf72_309c2382d253row8_col4{
#             background-color:  #fee1d4;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row4_col3{
#             background-color:  #fee4d8;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row4_col4{
#             background-color:  #ffece4;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row5_col1,#T_3700fa51_3fe7_11eb_bf72_309c2382d253row21_col3,#T_3700fa51_3fe7_11eb_bf72_309c2382d253row38_col2,#T_3700fa51_3fe7_11eb_bf72_309c2382d253row38_col4{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row5_col2{
#             background-color:  #fdd4c2;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row5_col3{
#             background-color:  #fdcebb;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row5_col4{
#             background-color:  #feeae0;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row6_col1,#T_3700fa51_3fe7_11eb_bf72_309c2382d253row34_col4{
#             background-color:  #9a0c14;
#             color:  #f1f1f1;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row6_col2,#T_3700fa51_3fe7_11eb_bf72_309c2382d253row35_col1,#T_3700fa51_3fe7_11eb_bf72_309c2382d253row38_col1{
#             background-color:  #fdc7b2;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row6_col3,#T_3700fa51_3fe7_11eb_bf72_309c2382d253row7_col3{
#             background-color:  #ffeee6;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row7_col1{
#             background-color:  #b51318;
#             color:  #f1f1f1;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row7_col2{
#             background-color:  #fcbca2;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row7_col4{
#             background-color:  #fee5d9;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row8_col1,#T_3700fa51_3fe7_11eb_bf72_309c2382d253row35_col3{
#             background-color:  #fc8d6d;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row8_col2{
#             background-color:  #fcb499;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row8_col3,#T_3700fa51_3fe7_11eb_bf72_309c2382d253row12_col2{
#             background-color:  #fc8262;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row9_col1,#T_3700fa51_3fe7_11eb_bf72_309c2382d253row24_col1,#T_3700fa51_3fe7_11eb_bf72_309c2382d253row24_col4{
#             background-color:  #f34a36;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row9_col2{
#             background-color:  #fcaa8d;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row9_col3,#T_3700fa51_3fe7_11eb_bf72_309c2382d253row12_col3{
#             background-color:  #fcaf93;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row9_col4{
#             background-color:  #fedccd;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row10_col1{
#             background-color:  #e32f27;
#             color:  #f1f1f1;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row10_col2,#T_3700fa51_3fe7_11eb_bf72_309c2382d253row10_col3,#T_3700fa51_3fe7_11eb_bf72_309c2382d253row33_col1{
#             background-color:  #fca082;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row10_col4{
#             background-color:  #fdd7c6;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row11_col1{
#             background-color:  #7a0510;
#             color:  #f1f1f1;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row11_col2,#T_3700fa51_3fe7_11eb_bf72_309c2382d253row18_col4{
#             background-color:  #fc9070;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row11_col3{
#             background-color:  #fcab8f;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row11_col4{
#             background-color:  #fdd1be;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row12_col1,#T_3700fa51_3fe7_11eb_bf72_309c2382d253row37_col4{
#             background-color:  #77040f;
#             color:  #f1f1f1;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row12_col4{
#             background-color:  #fdcbb6;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row13_col1{
#             background-color:  #d52221;
#             color:  #f1f1f1;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row13_col2,#T_3700fa51_3fe7_11eb_bf72_309c2382d253row26_col1{
#             background-color:  #fb7656;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row13_col3{
#             background-color:  #fc7f5f;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row13_col4{
#             background-color:  #fcc4ad;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row14_col1,#T_3700fa51_3fe7_11eb_bf72_309c2382d253row19_col2{
#             background-color:  #ef3c2c;
#             color:  #f1f1f1;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row14_col2{
#             background-color:  #fb6c4c;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row14_col3,#T_3700fa51_3fe7_11eb_bf72_309c2382d253row29_col2{
#             background-color:  #ac1117;
#             color:  #f1f1f1;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row14_col4,#T_3700fa51_3fe7_11eb_bf72_309c2382d253row31_col1{
#             background-color:  #fcb99f;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row15_col1,#T_3700fa51_3fe7_11eb_bf72_309c2382d253row37_col3{
#             background-color:  #fca486;
#             color:  #000000;
#         }#T_3700fa51_3fe7_11eb_bf72_309c2382d253row15_col2,#T_3700fa51_3fe7_11eb_bf72_309c2382d253row1

# %% [markdown]
# # New cases graph<a name="new_cases_graph"></a>

# %%
plt.figure(figsize=(30,12))
plt.title('New cases in Greece (7 November 2020 - today)', fontsize=30)
plt.ylabel('New Cases', fontsize=30)
plt.xlabel('Date', fontsize=30)
plt.xticks(rotation=90)
plt.tick_params(axis='x', labelsize=17)
plt.tick_params(axis='y', labelsize=25)
plt.plot(df_copy['Date_reported'], df_copy['New_cases'])

# %% [markdown]
# # New deaths graph<a name="new_deaths_graph"></a>

# %%
plt.figure(figsize=(30,12))
plt.title('New deaths in Greece (7 November 2020 - today)',fontsize=30)
plt.ylabel('New Deaths',fontsize=30)
plt.xlabel('Date',fontsize=30)
plt.xticks(rotation=90)
plt.tick_params(axis='y', labelsize=25)
plt.tick_params(axis='x', labelsize=18)
plt.plot(df_copy['Date_reported'], df_copy['New_deaths'])

# %% [markdown]
# # Total cases graph<a name="total_cases_graph"></a>

# %%
plt.figure(figsize=(30,12))
plt.title('Total cases in Greece (7 November 2020 - today)',fontsize=30)
plt.ylabel('Total Cases',fontsize=30)
plt.xlabel('Date',fontsize=30)
plt.xticks(rotation=90)
plt.tick_params(axis='x', labelsize=18)
plt.tick_params(axis='y', labelsize=25)
plt.plot(df_copy['Date_reported'], df_copy['Total_cases'])

# %% [markdown]
# # Total deaths graph<a name="total_deaths_graph"></a>

# %%
plt.figure(figsize=(30,12))
plt.title('Total deaths in Greece (7 November 2020 - today)',fontsize=30)
plt.ylabel('Total Deaths',fontsize=30)
plt.xlabel('Date',fontsize=30)
plt.xticks(rotation=90)
plt.tick_params(axis='x', labelsize=18)
plt.tick_params(axis='y', labelsize=25)
plt.plot(df_copy['Date_reported'], df_copy['Total_deaths'])

# %% [markdown]
# ## Using Prophet to predict covid-19 behavior to 1 week from today

# %%
from fbprophet import Prophet

# %%
new_cases=df_copy.groupby('Date_reported').sum()['New_cases'].reset_index()
new_deaths=df_copy.groupby('Date_reported').sum()['New_deaths'].reset_index()
total_cases=df_copy.groupby('Date_reported').sum()['Total_cases'].reset_index()
total_deaths=df_copy.groupby('Date_reported').sum()['Total_deaths'].reset_index()

# %% [markdown]
# ## Prediction of Total Cases<a name="prediction_total_cases"></a>

# %%
total_cases.tail()
# Out:
#    Date_reported  Total_cases
# 34    2020-12-11       122648
# 35    2020-12-12       123842
# 36    2020-12-13       124534
# 37    2020-12-14       125173
# 38    2020-12-15       126372

# %%
total_cases.columns=['ds','y']

# %%
m=Prophet(interval_width=0.95)
m.fit(total_cases)
future_total_cases=m.make_future_dataframe(periods=4)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast_total_cases=m.predict(future_total_cases)
forecast_total_cases[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(4)
# Out:
#            ds           yhat     yhat_lower     yhat_upper
# 39 2020-12-16  128091.438740  127686.077403  128483.122217
# 40 2020-12-17  129655.444193  128630.213722  130703.591156
# 41 2020-12-18  131061.422013  129206.486714  132886.556827
# 42 2020-12-19  132242.910457  129479.397964  134817.061808

# %%
forecast_total_cases_plot=m.plot(forecast_total_cases)

# %%
forecast_total_cases_plot=m.plot_components(forecast_total_cases)

# %% [markdown]
# ## Prediction of total deaths<a name="prediction_total_deaths"></a>

# %%
total_deaths.tail()
# Out:
#    Date_reported  Total_deaths
# 34    2020-12-11          3472
# 35    2020-12-12          3540
# 36    2020-12-13          3625
# 37    2020-12-14          3687
# 38    2020-12-15          3785

# %%
total_deaths.columns=['ds','y']

# %%
m=Prophet(interval_width=0.95)
m.fit(total_deaths)
future_total_deaths=m.make_future_dataframe(periods=4)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast_total_deaths=m.predict(future_total_deaths)
forecast_total_deaths[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(4)
# Out:
#            ds         yhat   yhat_lower   yhat_upper
# 39 2020-12-16  3876.307319  3864.686640  3888.556444
# 40 2020-12-17  3962.523983  3944.499669  3979.850286
# 41 2020-12-18  4049.492411  4020.110001  4074.458092
# 42 2020-12-19  4137.002053  4094.934195  4176.562741

# %%
forecast_total_deaths_plot=m.plot(forecast_total_deaths)

# %%
forecast_total_deaths_plot=m.plot_components(forecast_total_deaths)

# %% [markdown]
# ## Prediction of new deaths <a name="prediction_new_deaths"></a>

# %%
new_deaths.tail()
# Out:
#    Date_reported  New_deaths
# 34    2020-12-11         102
# 35    2020-12-12          68
# 36    2020-12-13          85
# 37    2020-12-14          62
# 38    2020-12-15          98

# %%
new_deaths.columns=['ds','y']

# %%
m=Prophet(interval_width=0.95)
m.fit(new_deaths)
future_new_deaths=m.make_future_dataframe(periods=4)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast_new_deaths=m.predict(future_new_deaths)
forecast_new_deaths[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(4)
# Out:
#            ds        yhat  yhat_lower  yhat_upper
# 39 2020-12-16  106.036596   71.103671  141.265971
# 40 2020-12-17  109.032819   79.498723  140.800016
# 41 2020-12-18  113.429998   78.905203  147.460549
# 42 2020-12-19  114.281074   79.844905  148.956576

# %%
forecast_new_deaths_plot=m.plot(forecast_new_deaths)

# %%
forecast_new_deaths_plot=m.plot_components(forecast_new_deaths)

# %% [markdown]
# ## Prediction of new cases<a name="prediction_new_cases"></a>

# %%
new_cases.tail()
# Out:
#    Date_reported  New_cases
# 34    2020-12-11       1395
# 35    2020-12-12       1194
# 36    2020-12-13        692
# 37    2020-12-14        639
# 38    2020-12-15       1199

# %%
new_cases.columns=['ds','y']

# %%
m=Prophet(interval_width=0.95)
m.fit(new_cases)
future_new_cases=m.make_future_dataframe(periods=4)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast_new_cases=m.predict(future_new_cases)
forecast_new_cases[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(4)
# Out:
#            ds         yhat  yhat_lower   yhat_upper
# 39 2020-12-16  1473.898798  956.312288  1946.254766
# 40 2020-12-17  1474.956600  987.064347  1937.781101
# 41 2020-12-18  1202.217639  700.954092  1734.864797
# 42 2020-12-19   929.755224  414.513850  1431.629334

# %%
forecast_new_cases_plot=m.plot(forecast_new_cases)

# %%
forecast_new_cases_plot=m.plot_components(forecast_new_cases)
